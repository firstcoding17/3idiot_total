# %% [markdown]
# 데이터 셋 형태 확인

# %%
import pandas as pd
import ast





#데이터 확인


Train = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(학습용데이터).csv', encoding='euc=kr')
Test = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(제출용데이터).csv', encoding='euc=kr')

#feature_group_A => x
data = ast.literal_eval(Train['Feature_Group_A'][0])
print(len(data))

#feature_group_B => y
data = ast.literal_eval(Train['Feature_Group_B'][0])
print(len(data))

#feature_group_C => z

#feature_group_C는 데이터가 str형태라서 딕셔너리로 변환하는 코드
data = ast.literal_eval(Train['Feature_Group_C'][0])
#딕셔너리 형태 'numstrings': 3312, 'avlength': 24.9393115942029, 'printabledist': [5963, 67, 449, 124, 398, 49, 90, 154, 326, 218, 65, 103, 491, 306, 802, 451, 1097, 727, 615, 602, 712, 633, 589, 508, 638, 529, 668, 759, 853, 531, 687, 738, 1020, 1084, 294, 733, 760, 831, 427, 336, 383, 782, 113, 83, 612, 327, 376, 542, 1055, 289, 527, 812, 883, 489, 558, 658, 314, 283, 145, 103, 223, 91, 99, 412, 244, 3157, 869, 1713, 1846, 5152, 913, 973, 1322, 2815, 321, 306, 2263, 990, 3001, 3620, 1423, 200, 3392, 2378, 4119, 1238, 438, 985, 806, 851, 113, 123, 181, 100, 75, 86], 'printables': 82599, 'entropy': 5.8347296238951945, 'paths': 0, 'urls': 39, 'registry': 0, 'MZ': 8
print(len(data['printabledist']))
print(type(data['numstrings']))
print(type(data['avlength']))
print(type(data['printables']))
# Out:
# 256
# 256
# 96
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
#차원 축소

# %% [markdown]
# **3AutoML 모델 이용**
#
# https://colab.research.google.com/github/rpi-techfundamentals/spring2019-materials/blob/master/14-automl/01_auto_ml_tpot.ipynb#scrollTo=uhBlHuGpO2n6

# %%
# Install tpot on the server
# !pip install tpot
# !pip install -U scikit-learn
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 5.1 MB/s
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.19.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.4.1)
# Collecting deap>=1.2
#   Downloading deap-1.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 40.3 MB/s
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.7/dist-packages (from tpot) (4.62.3)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from tpot) (0.22.2.post1)
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#      |████████████████████████████████| 173.5 MB 14 kB/s
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.0.1)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->tpot) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from update-checker>=0.16->tpot) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.24.3)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11952 sha256=e6c946d9b1349c68afa0120a3eb3b4da77df10b217c589f00dbae21d445bacf1
#   Stored in directory: /root/.cache/pip/wheels/e2/d2/79/eaf81edb391e27c87f51b8ef901ecc85a5363dc96b8b8d71e3
# Successfully built stopit
# Installing collected packages: xgboost, update-checker, stopit, deap, tpot
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed deap-1.3.1 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0 xgboost-1.5.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.22.2.post1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.1 MB)
#      |████████████████████████████████| 23.1 MB 1.4 MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-1.0 threadpoolctl-3.0.0

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np


from tpot import TPOTClassifier

# %%
#데이터 불러오기
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
from scipy.stats import skew, kurtosis
Train = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(학습용데이터).csv', encoding='euc=kr')
Test = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(제출용데이터).csv', encoding='euc=kr')

A = ast.literal_eval(Train['Feature_Group_A'][0])
print(kurtosis(A))
print(skew(A))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9905a128f7f4> in <module>()
#       3 Test = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(제출용데이터).csv', encoding='euc=kr')
#       4
# ----> 5 A = ast.literal_eval(Train['Feature_Group_A'][0])
#       6 print(kurtosis(A))
#       7 print(skew(A))
#
# NameError: name 'ast' is not defined

# %%
import pandas as pd
import ast
from scipy.stats import skew, kurtosis

#데이터 전처리

Train = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(학습용데이터).csv', encoding='euc=kr')
Test = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(제출용데이터).csv', encoding='euc=kr')

#데이터 프레임 생성

#테스트 피쳐
data = ast.literal_eval(Train['Feature_Group_C'][0])

A = ast.literal_eval(Train['Feature_Group_A'][0])

Askew = skew(A)

Akurtosis = kurtosis(A,fisher=True)

A = np.array(A)
A = np.std(A)



B = ast.literal_eval(Train['Feature_Group_B'][0])


Bskew = skew(B)

Bkurtosis = kurtosis(B,fisher=True)

B = np.array(B)
B = np.std(B)

printabledskew = skew(data['printabledist'])

printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

printabled = np.array(data['printabledist'])


printabled = np.std(printabled)



df_train_features = pd.DataFrame({
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                  'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'numstrings' : data['numstrings'],
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                  'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,                                 
                                  'printables' : data['printables'],
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ'],

                                  
},index=[0])
for i in range(1,len(Train)):
  data = ast.literal_eval(Train['Feature_Group_C'][i])

  A = ast.literal_eval(Train['Feature_Group_A'][i])

  Askew = skew(A)

  Akurtosis = kurtosis(A,fisher=True)

  A = np.array(A)
  A = np.std(A)



  B = ast.literal_eval(Train['Feature_Group_B'][i])


  Bskew = skew(B)

  Bkurtosis = kurtosis(B,fisher=True)

  B = np.array(B)
  B = np.std(B)

  printabledskew = skew(data['printabledist'])

  printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

  printabled = np.array(data['printabledist'])


  printabled = np.std(printabled)


  new_df ={
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                   'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'numstrings' : data['numstrings'],
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                   'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'printables' : data['printables'],
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
}
  new_df = pd.DataFrame(new_df,index=[i])

  df_train_features = pd.concat([df_train_features,new_df], sort=False)


  



#테스트 피처


data = ast.literal_eval(Test['Feature_Group_C'][0])

A = ast.literal_eval(Test['Feature_Group_A'][0])

Askew = skew(A)

Akurtosis = kurtosis(A,fisher=True)

A = np.array(A)
A = np.std(A)

B = ast.literal_eval(Test['Feature_Group_B'][0])

Bskew = skew(B)

Bkurtosis = kurtosis(B,fisher=True)

B = np.array(B)
B = np.std(B)


printabledskew = skew(data['printabledist'])

printabledkurtosis = kurtosis(data['printabledist'],fisher=True)


printabled = np.array(data['printabledist'])
printabled = np.std(printabled)



df_test_features = pd.DataFrame({
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                  'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'numstrings' : data['numstrings'],
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                 'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'printables' : data['printables'],
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
},index=[0])



for i in range(1,len(Test)):
  data = ast.literal_eval(Test['Feature_Group_C'][i])

  A = ast.literal_eval(Test['Feature_Group_A'][i])

  Askew = skew(A)

  Akurtosis = kurtosis(A,fisher=True)

  A = np.array(A)
  A = np.std(A)



  B = ast.literal_eval(Test['Feature_Group_B'][i])


  Bskew = skew(B)

  Bkurtosis = kurtosis(B,fisher=True)

  B = np.array(B)
  B = np.std(B)

  printabledskew = skew(data['printabledist'])

  printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

  printabled = np.array(data['printabledist'])


  printabled = np.std(printabled)


  new_df ={
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                   'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'numstrings' : data['numstrings'],
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                   'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'printables' : data['printables'],
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
}
  new_df = pd.DataFrame(new_df,index=[i])

  df_test_features = pd.concat([df_test_features,new_df], sort=False)




df_train_label = Train['label']

# %%
df_train_features.style.hide_index()
df_test_features.style.hide_index()

# Convert to numpy arrays
training_features = np.array(df_train_features)
testing_features = np.array(df_test_features)






# Sklearn wants the labels as one-dimensional vectors

training_targets = np.array(df_train_label).reshape((-1,))

# %%
# Create a tpot object with a few parameters
tpot = TPOTClassifier(generations=20,
                      population_size = 50,
                      verbosity = 2,
                      random_state = 42,
                      scoring = 'f1'
                      )

# %%
tpot.fit(training_features, training_targets)
# Out:
# Optimization Progress:   0%|          | 0/1050 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.8872150471604467
#
# Generation 2 - Current best internal CV score: 0.888003469949
#
# Generation 3 - Current best internal CV score: 0.888003469949
#
# Generation 4 - Current best internal CV score: 0.8944359927357525
#
# Generation 5 - Current best internal CV score: 0.8944359927357525
#
# Generation 6 - Current best internal CV score: 0.894684081989892
#
# Generation 7 - Current best internal CV score: 0.894684081989892
#
# Generation 8 - Current best internal CV score: 0.8966051111977993
#
# Generation 9 - Current best internal CV score: 0.8966051111977993
#
# Generation 10 - Current best internal CV score: 0.8966431465619575
#
# Generation 11 - Current best internal CV score: 0.8966431465619575
#
# Generation 12 - Current best internal CV score: 0.8978683849462374
#
# Generation 13 - Current best internal CV score: 0.8978816985887697
#
#
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), bootstrap=False, criterion=entropy, max_features=0.25, min_samples_leaf=3, min_samples_split=4, n_estimators=100)
# TPOTClassifier(generations=20, population_size=50, random_state=42,
#                scoring='f1', verbosity=2)

# %%
# Show the final model
print(tpot.fitted_pipeline_)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=0.25, min_samples_leaf=3,
#                                         min_samples_split=4,
#                                         random_state=42))])

# %%
# Export the pipeline as a python script file
tpot.export('tpot_exported_pipeline2.py')

# %%
# Import file management
from google.colab import files
# Download the pipeline for local use
files.download('tpot_exported_pipeline2.py')

# %%
tpot.export
# Out:
# <bound method TPOTBase.export of TPOTClassifier(generations=12, population_size=50, random_state=42,
#                scoring='f1', verbosity=2)>

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from tpot.export_utils import set_param_recursive

# Average CV score on the training set was: 0.8917182991030398
exported_pipeline = make_pipeline(
    StackingEstimator(estimator=ExtraTreesClassifier(bootstrap=False, criterion="entropy", max_features=0.7500000000000001, min_samples_leaf=2, min_samples_split=6, n_estimators=100)),
    RandomForestClassifier(bootstrap=True, criterion="gini", max_features=0.2, min_samples_leaf=8, min_samples_split=4, n_estimators=100)
)

# %%
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

# %%
exported_pipeline.fit(training_features, training_targets)
# Out:
# Pipeline(steps=[('stackingestimator',
#                  StackingEstimator(estimator=ExtraTreesClassifier(criterion='entropy',
#                                                                   max_features=0.7500000000000001,
#                                                                   min_samples_leaf=2,
#                                                                   min_samples_split=6,
#                                                                   random_state=42))),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_features=0.2, min_samples_leaf=8,
#                                         min_samples_split=4,
#                                         random_state=42))])

# %%
results= exported_pipeline.predict(training_features)

# %%
print(results)
# Out:
# [1 1 0 ... 0 1 0]

# %%
print(testing_features)
# Out:
# [[5.18805258e+03 1.14771417e+04 1.56000000e+03 ... 1.08000000e+02
#   0.00000000e+00 5.00000000e+00]
#  [3.61134583e+02 7.25278948e+03 1.66400000e+03 ... 1.00000000e+00
#   0.00000000e+00 6.00000000e+00]
#  [4.12520049e+03 6.89399650e+03 1.11100000e+03 ... 0.00000000e+00
#   0.00000000e+00 4.00000000e+00]
#  ...
#  [7.08648314e+03 9.80985779e+03 4.52300000e+03 ... 3.70000000e+01
#   0.00000000e+00 1.00000000e+00]
#  [8.62528566e+03 1.66449631e+04 5.34700000e+03 ... 2.00000000e+00
#   1.40000000e+01 4.00000000e+00]
#  [2.10244063e+03 1.12426131e+04 5.06300000e+03 ... 1.00000000e+00
#   1.00000000e+00 1.10000000e+01]]

# %%
results= exported_pipeline.predict(testing_features)

# %% [markdown]
# 3번째

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from tpot.export_utils import set_param_recursive


# Average CV score on the training set was: 0.8978816985887697
exported_pipeline = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False, interaction_only=False),
    RandomForestClassifier(bootstrap=False, criterion="entropy", max_features=0.25, min_samples_leaf=3, min_samples_split=4, n_estimators=100)
)

# %%
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

# %%
exported_pipeline.fit(training_features, training_targets)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=0.25, min_samples_leaf=3,
#                                         min_samples_split=4,
#                                         random_state=42))])

# %%
results = exported_pipeline.predict(testing_features)

# %%
test_label = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/세얼간이_1차.csv')

df_test_label = pd.DataFrame({'분석대상': Test['분석대상'][0],
                              '정답지' : results[0]
                                  
},index=[0])

for i in range(1,len(Test)):
  new_df_test_label = {'분석대상': Test['분석대상'][i],
                              '정답지' : int(results[i])
                                  
}
  new_df_test_label = pd.DataFrame(new_df_test_label,index=[i])

  df_test_label = pd.concat([df_test_label,new_df_test_label], sort=False)
df_test_label.to_csv('/content/gdrive/MyDrive/hoseo_AI/세얼간이_3_1차.csv',index=False)

# %% [markdown]
# 실험

# %% [markdown]
# 마지막
#
# 차원 축소 + SVM

# %%
import pandas as pd
import ast
from scipy.stats import skew, kurtosis

#데이터 전처리

Train = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(학습용데이터).csv', encoding='euc=kr')
Test = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/AI_탐지트랙_대회(제출용데이터).csv', encoding='euc=kr')

#데이터 프레임 생성

#테스트 피쳐
data = ast.literal_eval(Train['Feature_Group_C'][0])

A = ast.literal_eval(Train['Feature_Group_A'][0])

Askew = skew(A)

Akurtosis = kurtosis(A,fisher=True)

A = np.array(A)
A = np.std(A)



B = ast.literal_eval(Train['Feature_Group_B'][0])


Bskew = skew(B)

Bkurtosis = kurtosis(B,fisher=True)

B = np.array(B)
B = np.std(B)

printabledskew = skew(data['printabledist'])

printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

printabled = np.array(data['printabledist'])


printabled = np.std(printabled)



df_train_features = pd.DataFrame({
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                  'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                  'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,                                 
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']

                                  
},index=[0])
for i in range(1,len(Train)):
  data = ast.literal_eval(Train['Feature_Group_C'][i])

  A = ast.literal_eval(Train['Feature_Group_A'][i])

  Askew = skew(A)

  Akurtosis = kurtosis(A,fisher=True)

  A = np.array(A)
  A = np.std(A)



  B = ast.literal_eval(Train['Feature_Group_B'][i])


  Bskew = skew(B)

  Bkurtosis = kurtosis(B,fisher=True)

  B = np.array(B)
  B = np.std(B)

  printabledskew = skew(data['printabledist'])

  printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

  printabled = np.array(data['printabledist'])


  printabled = np.std(printabled)


  new_df ={
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                   'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                   'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
}
  new_df = pd.DataFrame(new_df,index=[i])

  df_train_features = pd.concat([df_train_features,new_df], sort=False)


  



#테스트 피처


data = ast.literal_eval(Test['Feature_Group_C'][0])

A = ast.literal_eval(Test['Feature_Group_A'][0])

Askew = skew(A)

Akurtosis = kurtosis(A,fisher=True)

A = np.array(A)
A = np.std(A)

B = ast.literal_eval(Test['Feature_Group_B'][0])

Bskew = skew(B)

Bkurtosis = kurtosis(B,fisher=True)

B = np.array(B)
B = np.std(B)


printabledskew = skew(data['printabledist'])

printabledkurtosis = kurtosis(data['printabledist'],fisher=True)


printabled = np.array(data['printabledist'])
printabled = np.std(printabled)



df_test_features = pd.DataFrame({
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                  'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                 'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
},index=[0])



for i in range(1,len(Test)):
  data = ast.literal_eval(Test['Feature_Group_C'][i])

  A = ast.literal_eval(Test['Feature_Group_A'][i])

  Askew = skew(A)

  Akurtosis = kurtosis(A,fisher=True)

  A = np.array(A)
  A = np.std(A)



  B = ast.literal_eval(Test['Feature_Group_B'][i])


  Bskew = skew(B)

  Bkurtosis = kurtosis(B,fisher=True)

  B = np.array(B)
  B = np.std(B)

  printabledskew = skew(data['printabledist'])

  printabledkurtosis = kurtosis(data['printabledist'],fisher=True)

  printabled = np.array(data['printabledist'])


  printabled = np.std(printabled)


  new_df ={
                                  'Feature_Group_A': A,
                                  'Feature_Group_A_skew': Askew,
                                  'Feature_Group_A_kurtosis':Akurtosis,
                                  'Feature_Group_B': B,
                                   'Feature_Group_B_skew': Bskew,
                                  'Feature_Group_B_kurtosis':Bkurtosis,
                                  'avlength': data['avlength'],
                                  'printabledist':printabled,
                                   'printabledist_skew': printabledskew,
                                  'printabledist_kurtosis':printabledkurtosis,   
                                  'entropy': data['entropy'],
                                  'paths' : data['paths'],
                                  'urls' : data['urls'],
                                  'registry' : data['registry'],
                                  'MZ' : data['MZ']
}
  new_df = pd.DataFrame(new_df,index=[i])

  df_test_features = pd.concat([df_test_features,new_df], sort=False)




df_train_label = Train['label']

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

df_train_features.style.hide_index()
df_test_features.style.hide_index()



train_df = StandardScaler().fit_transform(df_train_features)
test_df = StandardScaler().fit_transform(df_test_features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
#fit( )과 transform( ) 을 호출하여 PCA 변환 데이터 반환



pca.fit(train_df)
train = pca.transform(train_df)
print(train.shape)

pca.fit(test_df)
test = pca.transform(test_df)
print(test.shape)

print(test)
print(train)
#차원 축소 끝
# Out:
# (10000, 3)
# (5000, 3)
# [[ 1.43757338  0.50633332  1.10486311]
#  [-3.00660219  2.41389801  0.9974405 ]
#  [ 1.52702922 -1.24184843 -0.57354039]
#  ...
#  [-0.74463162 -0.69901187 -0.18909732]
#  [-1.39262155  1.45603197  0.41935143]
#  [ 1.32785322  4.1629335  -0.7708711 ]]
# [[ 2.57366017 -0.43071638 -0.78754396]
#  [ 1.13478847 -0.32824011  0.41737174]
#  [-4.78147035  0.74383313 -0.21950086]
#  ...
#  [-0.08436695 -0.63296101 -0.76704223]
#  [-1.00876099 -0.27082676 -0.74890614]
#  [-2.79280309  0.44498018 -1.25472548]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


training_targets = np.array(df_train_label).reshape((-1,))

# %%
xtrain,xtest,ytrain,ytest=train_test_split(train, training_targets, test_size=0.2, random_state=42)

# %%
scores = []
for thisC in [*range(1,100)]:
    svc=SVC(kernel='rbf',C=thisC)
    model=svc.fit(xtrain,ytrain)
    scoreTrain=model.score(xtrain,ytrain)
    scoreTest=model.score(xtest,ytest)
    print("rbf SVM : C:{}, training score:{:2f}, test score:{:2f}".format
          (thisC,scoreTrain, scoreTest))
    scores.append([scoreTrain, scoreTest])
# Out:
# rbf SVM : C:1, training score:0.726125, test score:0.721500
# rbf SVM : C:2, training score:0.730750, test score:0.726500
# rbf SVM : C:3, training score:0.730375, test score:0.726500
# rbf SVM : C:4, training score:0.730375, test score:0.727500
# rbf SVM : C:5, training score:0.730750, test score:0.728000
# rbf SVM : C:6, training score:0.738000, test score:0.735000
# rbf SVM : C:7, training score:0.745875, test score:0.745500
# rbf SVM : C:8, training score:0.746750, test score:0.746500
# rbf SVM : C:9, training score:0.748000, test score:0.748500
# rbf SVM : C:10, training score:0.747875, test score:0.748000
# rbf SVM : C:11, training score:0.747625, test score:0.747000
# rbf SVM : C:12, training score:0.748125, test score:0.748500
# rbf SVM : C:13, training score:0.747375, test score:0.748000
# rbf SVM : C:14, training score:0.748750, test score:0.748000
# rbf SVM : C:15, training score:0.748625, test score:0.747500
# rbf SVM : C:16, training score:0.748875, test score:0.747000
# rbf SVM : C:17, training score:0.748375, test score:0.747000
# rbf SVM : C:18, training score:0.748250, test score:0.746000
# rbf SVM : C:19, training score:0.748250, test score:0.746500
# rbf SVM : C:20, training score:0.748500, test score:0.747000
# rbf SVM : C:21, training score:0.749625, test score:0.748500
# rbf SVM : C:22, training score:0.749875, test score:0.747500
# rbf SVM : C:23, training score:0.750250, test score:0.747000
# rbf SVM : C:24, training score:0.750500, test score:0.748000
# rbf SVM : C:25, training score:0.750875, test score:0.748500
# rbf SVM : C:26, training score:0.750750, test score:0.748000
# rbf SVM : C:27, training score:0.750625, test score:0.747500
# rbf SVM : C:28, training score:0.750875, test score:0.747000
# rbf SVM : C:29, training score:0.750875, test score:0.747000
# rbf SVM : C:30, training score:0.751000, test score:0.746500
# rbf SVM : C:31, training score:0.751125, test score:0.746500
# rbf SVM : C:32, training score:0.750875, test score:0.746000
# rbf SVM : C:33, training score:0.751250, test score:0.746000
# rbf SVM : C:34, training score:0.751625, test score:0.745000
# rbf SVM : C:35, training score:0.751500, test score:0.746500
# rbf SVM : C:36, training score:0.751250, test score:0.745000
# rbf SVM : C:37, training score:0.751875, test score:0.745000
# rbf SVM : C:38, training score:0.752125, test score:0.745500
# rbf SVM : C:39, training score:0.751875, test score:0.745500
# rbf SVM : C:40, training score:0.751750, test score:0.745500
# rbf SVM : C:41, training score:0.751875, test score:0.744500
# rbf SVM : C:42, training score:0.751375, test score:0.745000
# rbf SVM : C:43, training score:0.751125, test score:0.746000
# rbf SVM : C:44, training score:0.751125, test score:0.746000
# rbf SVM : C:45, training score:0.751000, test score:0.746000
# rbf SVM : C:46, training score:0.751250, test score:0.745500
# rbf SVM : C:47, training score:0.751000, test score:0.745500
# rbf SVM : C:48, training score:0.751125, test score:0.745000
# rbf SVM : C:49, training score:0.750875, test score:0.745000
# rbf SVM : C:50, training score:0.751125, test score:0.745000
# rbf SVM : C:51, training score:0.751125, test score:0.745000
# rbf SVM : C:52, training score:0.750875, test score:0.747500
# rbf SVM : C:53, training score:0.751000, test score:0.747500
# rbf SVM : C:54, training score:0.751000, test score:0.746500
# rbf SVM : C:55, training score:0.751000, test score:0.747000
# rbf SVM : C:56, training score:0.751125, test score:0.747000
# rbf SVM : C:57, training score:0.751125, test score:0.747000
# rbf SVM : C:58, training score:0.751375, test score:0.747000
# rbf SVM : C:59, training score:0.751250, test score:0.747000
# rbf SVM : C:60, training score:0.751375, test score:0.747000
# rbf SVM : C:61, training score:0.751500, test score:0.747000
# rbf SVM : C:62, training score:0.751375, test score:0.747500
# rbf SVM : C:63, training score:0.751375, test score:0.747500
# rbf SVM : C:64, training score:0.751250, test score:0.748000
# rbf SVM : C:65, training score:0.751750, test score:0.747500
# rbf SVM : C:66, training score:0.752250, test score:0.747000
# rbf SVM : C:67, training score:0.752000, test score:0.747000
# rbf SVM : C:68, training score:0.752125, test score:0.747000
# rbf SVM : C:69, training score:0.751875, test score:0.747000
# rbf SVM : C:70, training score:0.751875, test score:0.747000
# rbf SVM : C:71, training score:0.751875, test score:0.747000
# rbf SVM : C:72, training score:0.751875, test score:0.747500
# rbf SVM : C:73, training score:0.752125, test score:0.747500
# rbf SVM : C:74, training score:0.752000, test score:0.748000
# rbf SVM : C:75, training score:0.752000, test score:0.747500
# rbf SVM : C:76, training score:0.751750, test score:0.747500
# rbf SVM : C:77, training score:0.751875, test score:0.747500
# rbf SVM : C:78, training score:0.752250, test score:0.747500
# rbf SVM : C:79, training score:0.752625, test score:0.747500
# rbf SVM : C:80, training score:0.752750, test score:0.748000
# rbf SVM : C:81, training score:0.752750, test score:0.748000
# rbf SVM : C:82, training score:0.752625, test score:0.748000
# rbf SVM : C:83, training score:0.752375, test score:0.748000
# rbf SVM : C:84, training score:0.752250, test score:0.748500
# rbf SVM : C:85, training score:0.752250, test score:0.747500
# rbf SVM : C:86, training score:0.752125, test score:0.748000
# rbf SVM : C:87, training score:0.752375, test score:0.748000
# rbf SVM : C:88, training score:0.752375, test score:0.748000
# rbf SVM : C:89, training score:0.752375, test score:0.748500
# rbf SVM : C:90, training score:0.752375, test score:0.748500
# rbf SVM : C:91, training score:0.752125, test score:0.748000
# rbf SVM : C:92, training score:0.752250, test score:0.749000
# rbf SVM : C:93, training score:0.752125, test score:0.748500
# rbf SVM : C:94, training score:0.752500, test score:0.748500
# rbf SVM : C:95, training score:0.752500, test score:0.748500
# rbf SVM : C:96, training score:0.752625, test score:0.748500
# rbf SVM : C:97, training score:0.752875, test score:0.749000
# rbf SVM : C:98, training score:0.752625, test score:0.748000
# rbf SVM : C:99, training score:0.752500, test score:0.748000

# %%
best = 0.776000
getc = 0
getg = 0
for thisC in [*range(22,40)]:
  for j in range(1,100):
    svc=SVC(kernel='rbf',C=thisC, gamma= j )
    model=svc.fit(xtrain,ytrain)
    scoreTrain=model.score(xtrain,ytrain)
    scoreTest=model.score(xtest,ytest)
    print("rbf SVM : C:{}, g:{} training score:{:2f}, test score:{:2f}".format
          (thisC,j,scoreTrain, scoreTest))
    if best < scoreTest:
      best = scoreTest
      getc = thisC
      getg = j
# Out:
# rbf SVM : C:22, g:1 training score:0.778000, test score:0.759500
# rbf SVM : C:22, g:2 training score:0.795875, test score:0.765500
# rbf SVM : C:22, g:3 training score:0.809875, test score:0.753500
# rbf SVM : C:22, g:4 training score:0.825500, test score:0.758500
# rbf SVM : C:22, g:5 training score:0.839000, test score:0.767500
# rbf SVM : C:22, g:6 training score:0.850000, test score:0.772000
# rbf SVM : C:22, g:7 training score:0.856625, test score:0.768500
# rbf SVM : C:22, g:8 training score:0.860125, test score:0.762000
# rbf SVM : C:22, g:9 training score:0.868125, test score:0.759000
# rbf SVM : C:22, g:10 training score:0.873375, test score:0.756000
# rbf SVM : C:22, g:11 training score:0.876750, test score:0.758500
# rbf SVM : C:22, g:12 training score:0.880625, test score:0.759000
# rbf SVM : C:22, g:13 training score:0.884625, test score:0.754500
# rbf SVM : C:22, g:14 training score:0.888875, test score:0.753000
# rbf SVM : C:22, g:15 training score:0.892000, test score:0.752000
# rbf SVM : C:22, g:16 training score:0.895250, test score:0.751500
# rbf SVM : C:22, g:17 training score:0.900250, test score:0.750500
# rbf SVM : C:22, g:18 training score:0.903875, test score:0.751000
# rbf SVM : C:22, g:19 training score:0.908250, test score:0.750000
# rbf SVM : C:22, g:20 training score:0.910875, test score:0.750000
# rbf SVM : C:22, g:21 training score:0.914500, test score:0.749500
# rbf SVM : C:22, g:22 training score:0.917750, test score:0.749000
# rbf SVM : C:22, g:23 training score:0.921125, test score:0.747500
# rbf SVM : C:22, g:24 training score:0.922250, test score:0.748000
# rbf SVM : C:22, g:25 training score:0.924625, test score:0.753000
# rbf SVM : C:22, g:26 training score:0.927125, test score:0.753500
# rbf SVM : C:22, g:27 training score:0.927625, test score:0.753000
# rbf SVM : C:22, g:28 training score:0.929125, test score:0.754000
# rbf SVM : C:22, g:29 training score:0.930000, test score:0.754500
# rbf SVM : C:22, g:30 training score:0.931625, test score:0.754000
# rbf SVM : C:22, g:31 training score:0.932750, test score:0.753000
# rbf SVM : C:22, g:32 training score:0.935250, test score:0.754000
# rbf SVM : C:22, g:33 training score:0.937250, test score:0.757500
# rbf SVM : C:22, g:34 training score:0.940500, test score:0.758000
# rbf SVM : C:22, g:35 training score:0.942500, test score:0.755500
# rbf SVM : C:22, g:36 training score:0.944000, test score:0.755000
# rbf SVM : C:22, g:37 training score:0.944750, test score:0.755500
# rbf SVM : C:22, g:38 training score:0.945250, test score:0.757000
# rbf SVM : C:22, g:39 training score:0.946000, test score:0.757500
# rbf SVM : C:22, g:40 training score:0.947625, test score:0.756500
# rbf SVM : C:22, g:41 training score:0.949375, test score:0.757000
# rbf SVM : C:22, g:42 training score:0.950125, test score:0.756500
# rbf SVM : C:22, g:43 training score:0.951000, test score:0.755500
# rbf SVM : C:22, g:44 training score:0.952375, test score:0.754500
# rbf SVM : C:22, g:45 training score:0.953125, test score:0.755000
# rbf SVM : C:22, g:46 training score:0.955000, test score:0.754000
# rbf SVM : C:22, g:47 training score:0.955250, test score:0.752500
# rbf SVM : C:22, g:48 training score:0.956250, test score:0.750500
# rbf SVM : C:22, g:49 training score:0.957250, test score:0.750500
# rbf SVM : C:22, g:50 training score:0.957875, test score:0.752500
# rbf SVM : C:22, g:51 training score:0.958250, test score:0.750500
# rbf SVM : C:22, g:52 training score:0.959000, test score:0.749500
# rbf SVM : C:22, g:53 training score:0.959875, test score:0.751500
# rbf SVM : C:22, g:54 training score:0.961250, test score:0.750500
# rbf SVM : C:22, g:55 training score:0.963125, test score:0.750500
# rbf SVM : C:22, g:56 training score:0.964250, test score:0.750500
# rbf SVM : C:22, g:57 training score:0.965000, test score:0.749500
# rbf SVM : C:22, g:58 training score:0.966000, test score:0.747500
# rbf SVM : C:22, g:59 training score:0.967500, test score:0.747500
# rbf SVM : C:22, g:60 training score:0.968250, test score:0.748000
# rbf SVM : C:22, g:61 training score:0.968875, test score:0.745500
# rbf SVM : C:22, g:62 training score:0.969625, test score:0.746000
# rbf SVM : C:22, g:63 training score:0.970000, test score:0.746000
# rbf SVM : C:22, g:64 training score:0.971250, test score:0.745500
# rbf SVM : C:22, g:65 training score:0.971625, test score:0.746500
# rbf SVM : C:22, g:66 training score:0.972750, test score:0.747000
# rbf SVM : C:22, g:67 training score:0.973500, test score:0.749000
# rbf SVM : C:22, g:68 training score:0.974250, test score:0.747500
# rbf SVM : C:22, g:69 training score:0.974750, test score:0.747500
# rbf SVM : C:22, g:70 training score:0.975250, test score:0.748000
# rbf SVM : C:22, g:71 training score:0.975500, test score:0.747000
# rbf SVM : C:22, g:72 training score:0.975875, test score:0.745500
# rbf SVM : C:22, g:73 training score:0.976875, test score:0.745500
# rbf SVM : C:22, g:74 training score:0.976875, test score:0.743500
# rbf SVM : C:22, g:75 training score:0.977375, test score:0.745500
# rbf SVM : C:22, g:76 training score:0.978000, test score:0.746500
# rbf SVM : C:22, g:77 training score:0.977875, test score:0.746500
# rbf SVM : C:22, g:78 training score:0.978625, test score:0.745000
# rbf SVM : C:22, g:79 training score:0.979125, test score:0.744000
# rbf SVM : C:22, g:80 training score:0.979250, test score:0.744500
# rbf SVM : C:22, g:81 training score:0.979500, test score:0.744500
# rbf SVM : C:22, g:82 training score:0.980375, test score:0.745000
# rbf SVM : C:22, g:83 training score:0.980875, test score:0.746500
# rbf SVM : C:22, g:84 training score:0.981375, test score:0.746000
# rbf SVM : C:22, g:85 training score:0.981750, test score:0.747000
# rbf SVM : C:22, g:86 training score:0.982625, test score:0.747000
# rbf SVM : C:22, g:87 training score:0.982750, test score:0.747000
# rbf SVM : C:22, g:88 training score:0.982875, test score:0.748500
# rbf SVM : C:22, g:89 training score:0.983125, test score:0.747000
# rbf SVM : C:22, g:90 training score:0.983750, test score:0.746000
# rbf SVM : C:22, g:91 training score:0.984125, test score:0.746000
# rbf SVM : C:22, g:92 training score:0.984875, test score:0.746500
# rbf SVM : C:22, g:93 training score:0.985250, test score:0.746500
# rbf SVM : C:22, g:94 training score:0.985375, test score:0.745500
# rbf SVM : C:22, g:95 training score:0.985625, test score:0.745000
# rbf SVM : C:22, g:96 training score:0.985750, test score:0.744000
# rbf SVM : C:22, g:97 training score:0.986000, test score:0.743500
# rbf SVM : C:22, g:98 training score:0.986500, test score:0.743500
# rbf SVM : C:22, g:99 training score:0.986750, test score:0.744000
# rbf SVM : C:23, g:1 training score:0.778375, test score:0.758500
# rbf SVM : C:23, g:2 training score:0.797250, test score:0.765500
# rbf SVM : C:23, g:3 training score:0.811000, test score:0.754500
# rbf SVM : C:23, g:4 training score:0.826750, test score:0.759500
# rbf SVM : C:23, g:5 training score:0.839625, test score:0.769500
# rbf SVM : C:23, g:6 training score:0.850375, test score:0.773000
# rbf SVM : C:23, g:7 training score:0.856750, test score:0.768000
# rbf SVM : C:23, g:8 training score:0.860625, test score:0.763000
# rbf SVM : C:23, g:9 training score:0.868375, test score:0.759000
# rbf SVM : C:23, g:10 training score:0.874125, test score:0.754500
# rbf SVM : C:23, g:11 training score:0.876625, test score:0.757000
# rbf SVM : C:23, g:12 training score:0.881125, test score:0.757500
# rbf SVM : C:23, g:13 training score:0.884750, test score:0.754000
# rbf SVM : C:23, g:14 training score:0.888625, test score:0.752500
# rbf SVM : C:23, g:15 training score:0.892875, test score:0.752500
# rbf SVM : C:23, g:16 training score:0.895875, test score:0.751500
# rbf SVM : C:23, g:17 training score:0.900875, test score:0.751500
# rbf SVM : C:23, g:18 training score:0.905250, test score:0.751000
# rbf SVM : C:23, g:19 training score:0.909375, test score:0.751500
# rbf SVM : C:23, g:20 training score:0.912500, test score:0.749500
# rbf SVM : C:23, g:21 training score:0.915750, test score:0.748000
# rbf SVM : C:23, g:22 training score:0.918125, test score:0.749000
# rbf SVM : C:23, g:23 training score:0.921625, test score:0.748000
# rbf SVM : C:23, g:24 training score:0.923250, test score:0.749000
# rbf SVM : C:23, g:25 training score:0.925750, test score:0.752000
# rbf SVM : C:23, g:26 training score:0.927750, test score:0.754000
# rbf SVM : C:23, g:27 training score:0.927875, test score:0.753500
# rbf SVM : C:23, g:28 training score:0.929125, test score:0.751500
# rbf SVM : C:23, g:29 training score:0.930500, test score:0.754000
# rbf SVM : C:23, g:30 training score:0.932250, test score:0.753500
# rbf SVM : C:23, g:31 training score:0.933250, test score:0.754000
# rbf SVM : C:23, g:32 training score:0.936125, test score:0.754500
# rbf SVM : C:23, g:33 training score:0.939250, test score:0.757500
# rbf SVM : C:23, g:34 training score:0.941000, test score:0.756500
# rbf SVM : C:23, g:35 training score:0.942625, test score:0.755000
# rbf SVM : C:23, g:36 training score:0.944375, test score:0.755500
# rbf SVM : C:23, g:37 training score:0.945125, test score:0.757000
# rbf SVM : C:23, g:38 training score:0.945750, test score:0.758000
# rbf SVM : C:23, g:39 training score:0.947000, test score:0.756500
# rbf SVM : C:23, g:40 training score:0.948875, test score:0.756500
# rbf SVM : C:23, g:41 training score:0.950125, test score:0.757500
# rbf SVM : C:23, g:42 training score:0.950625, test score:0.755000
# rbf SVM : C:23, g:43 training score:0.952125, test score:0.755000
# rbf SVM : C:23, g:44 training score:0.953125, test score:0.754500
# rbf SVM : C:23, g:45 training score:0.954000, test score:0.754000
# rbf SVM : C:23, g:46 training score:0.955125, test score:0.752500
# rbf SVM : C:23, g:47 training score:0.955875, test score:0.752000
# rbf SVM : C:23, g:48 training score:0.956875, test score:0.751500
# rbf SVM : C:23, g:49 training score:0.957500, test score:0.751000
# rbf SVM : C:23, g:50 training score:0.958375, test score:0.751500
# rbf SVM : C:23, g:51 training score:0.959125, test score:0.750500
# rbf SVM : C:23, g:52 training score:0.959500, test score:0.750000
# rbf SVM : C:23, g:53 training score:0.961250, test score:0.750500
# rbf SVM : C:23, g:54 training score:0.962500, test score:0.751000
# rbf SVM : C:23, g:55 training score:0.964000, test score:0.751500
# rbf SVM : C:23, g:56 training score:0.965125, test score:0.750000
# rbf SVM : C:23, g:57 training score:0.966375, test score:0.747500
# rbf SVM : C:23, g:58 training score:0.967375, test score:0.746000
# rbf SVM : C:23, g:59 training score:0.968500, test score:0.746000
# rbf SVM : C:23, g:60 training score:0.968875, test score:0.746000
# rbf SVM : C:23, g:61 training score:0.969625, test score:0.746000
# rbf SVM : C:23, g:62 training score:0.970000, test score:0.746500
# rbf SVM : C:23, g:63 training score:0.970750, test score:0.745000
# rbf SVM : C:23, g:64 training score:0.971750, test score:0.745500
# rbf SVM : C:23, g:65 training score:0.972750, test score:0.747000
# rbf SVM : C:23, g:66 training score:0.973500, test score:0.748000
# rbf SVM : C:23, g:67 training score:0.974125, test score:0.746500
# rbf SVM : C:23, g:68 training score:0.974875, test score:0.748500
# rbf SVM : C:23, g:69 training score:0.975125, test score:0.748500
# rbf SVM : C:23, g:70 training score:0.975375, test score:0.748000
# rbf SVM : C:23, g:71 training score:0.975750, test score:0.747500
# rbf SVM : C:23, g:72 training score:0.976750, test score:0.745500
# rbf SVM : C:23, g:73 training score:0.976875, test score:0.746000
# rbf SVM : C:23, g:74 training score:0.977375, test score:0.743500
# rbf SVM : C:23, g:75 training score:0.977875, test score:0.746000
# rbf SVM : C:23, g:76 training score:0.978125, test score:0.746500
# rbf SVM : C:23, g:77 training score:0.978875, test score:0.746000
# rbf SVM : C:23, g:78 training score:0.979125, test score:0.744500
# rbf SVM : C:23, g:79 training score:0.979375, test score:0.744500
# rbf SVM : C:23, g:80 training score:0.979750, test score:0.746000
# rbf SVM : C:23, g:81 training score:0.980375, test score:0.745000
# rbf SVM : C:23, g:82 training score:0.980875, test score:0.746000
# rbf SVM : C:23, g:83 training score:0.981625, test score:0.746500
# rbf SVM : C:23, g:84 training score:0.982000, test score:0.746500
# rbf SVM : C:23, g:85 training score:0.982750, test score:0.746500
# rbf SVM : C:23, g:86 training score:0.982875, test score:0.747000
# rbf SVM : C:23, g:87 training score:0.982875, test score:0.748500
# rbf SVM : C:23, g:88 training score:0.983375, test score:0.747500
# rbf SVM : C:23, g:89 training score:0.984125, test score:0.746500
# rbf SVM : C:23, g:90 training score:0.984625, test score:0.746000
# rbf SVM : C:23, g:91 training score:0.985375, test score:0.746500
# rbf SVM : C:23, g:92 training score:0.985375, test score:0.746000
# rbf SVM : C:23, g:93 training score:0.985250, test score:0.745500
# rbf SVM : C:23, g:94 training score:0.985500, test score:0.745000
# rbf SVM : C:23, g:95 training score:0.985750, test score:0.745500
# rbf SVM : C:23, g:96 training score:0.986125, test score:0.745000
# rbf SVM : C:23, g:97 training score:0.986500, test score:0.745000
# rbf SVM : C:23, g:98 training score:0.987000, test score:0.745000
# rbf SVM : C:23, g:99 training score:0.987125, test score:0.745000
# rbf SVM : C:24, g:1 training score:0.779000, test score:0.758500
# rbf SVM : C:24, g:2 training score:0.798500, test score:0.767500
# rbf SVM : C:24, g:3 training score:0.811375, test score:0.753500
# rbf SVM : C:24, g:4 training score:0.828500, test score:0.761500
# rbf SVM : C:24, g:5 training score:0.840875, test score:0.769500
# rbf SVM : C:24, g:6 training score:0.850250, test score:0.774000
# rbf SVM : C:24, g:7 training score:0.856750, test score:0.767500
# rbf SVM : C:24, g:8 training score:0.861250, test score:0.763000
# rbf SVM : C:24, g:9 training score:0.868875, test score:0.758500
# rbf SVM : C:24, g:10 training score:0.874875, test score:0.755000
# rbf SVM : C:24, g:11 training score:0.877625, test score:0.756000
# rbf SVM : C:24, g:12 training score:0.881125, test score:0.758000
# rbf SVM : C:24, g:13 training score:0.885000, test score:0.752500
# rbf SVM : C:24, g:14 training score:0.889875, test score:0.752000
# rbf SVM : C:24, g:15 training score:0.893250, test score:0.754000
# rbf SVM : C:24, g:16 training score:0.896500, test score:0.751500
# rbf SVM : C:24, g:17 training score:0.900875, test score:0.750500
# rbf SVM : C:24, g:18 training score:0.906625, test score:0.751000
# rbf SVM : C:24, g:19 training score:0.909875, test score:0.751500
# rbf SVM : C:24, g:20 training score:0.913125, test score:0.749000
# rbf SVM : C:24, g:21 training score:0.916500, test score:0.748000
# rbf SVM : C:24, g:22 training score:0.919250, test score:0.748500
# rbf SVM : C:24, g:23 training score:0.921875, test score:0.747500
# rbf SVM : C:24, g:24 training score:0.924125, test score:0.751000
# rbf SVM : C:24, g:25 training score:0.926000, test score:0.755500
# rbf SVM : C:24, g:26 training score:0.927500, test score:0.753500
# rbf SVM : C:24, g:27 training score:0.929375, test score:0.753500
# rbf SVM : C:24, g:28 training score:0.929500, test score:0.752500
# rbf SVM : C:24, g:29 training score:0.931000, test score:0.753000
# rbf SVM : C:24, g:30 training score:0.932500, test score:0.752500
# rbf SVM : C:24, g:31 training score:0.934375, test score:0.754500
# rbf SVM : C:24, g:32 training score:0.936625, test score:0.755500
# rbf SVM : C:24, g:33 training score:0.940500, test score:0.756500
# rbf SVM : C:24, g:34 training score:0.942500, test score:0.755500
# rbf SVM : C:24, g:35 training score:0.944000, test score:0.755000
# rbf SVM : C:24, g:36 training score:0.944750, test score:0.755500
# rbf SVM : C:24, g:37 training score:0.945000, test score:0.758000
# rbf SVM : C:24, g:38 training score:0.946375, test score:0.756500
# rbf SVM : C:24, g:39 training score:0.948000, test score:0.757000
# rbf SVM : C:24, g:40 training score:0.949750, test score:0.756000
# rbf SVM : C:24, g:41 training score:0.950625, test score:0.756000
# rbf SVM : C:24, g:42 training score:0.951000, test score:0.756000
# rbf SVM : C:24, g:43 training score:0.952625, test score:0.754500
# rbf SVM : C:24, g:44 training score:0.953375, test score:0.753500
# rbf SVM : C:24, g:45 training score:0.954875, test score:0.753000
# rbf SVM : C:24, g:46 training score:0.955250, test score:0.752500
# rbf SVM : C:24, g:47 training score:0.956875, test score:0.751000
# rbf SVM : C:24, g:48 training score:0.957250, test score:0.751000
# rbf SVM : C:24, g:49 training score:0.957875, test score:0.751500
# rbf SVM : C:24, g:50 training score:0.958750, test score:0.750500
# rbf SVM : C:24, g:51 training score:0.959500, test score:0.750000
# rbf SVM : C:24, g:52 training score:0.960625, test score:0.750000
# rbf SVM : C:24, g:53 training score:0.962000, test score:0.750500
# rbf SVM : C:24, g:54 training score:0.963625, test score:0.750500
# rbf SVM : C:24, g:55 training score:0.964375, test score:0.751500
# rbf SVM : C:24, g:56 training score:0.966125, test score:0.747000
# rbf SVM : C:24, g:57 training score:0.967375, test score:0.746000
# rbf SVM : C:24, g:58 training score:0.968375, test score:0.744500
# rbf SVM : C:24, g:59 training score:0.968750, test score:0.745500
# rbf SVM : C:24, g:60 training score:0.969250, test score:0.746500
# rbf SVM : C:24, g:61 training score:0.969875, test score:0.745000
# rbf SVM : C:24, g:62 training score:0.970625, test score:0.744500
# rbf SVM : C:24, g:63 training score:0.972000, test score:0.745000
# rbf SVM : C:24, g:64 training score:0.972500, test score:0.745000
# rbf SVM : C:24, g:65 training score:0.973250, test score:0.747000
# rbf SVM : C:24, g:66 training score:0.973875, test score:0.746000
# rbf SVM : C:24, g:67 training score:0.974625, test score:0.746500
# rbf SVM : C:24, g:68 training score:0.975250, test score:0.748000
# rbf SVM : C:24, g:69 training score:0.975375, test score:0.748500
# rbf SVM : C:24, g:70 training score:0.976000, test score:0.747500
# rbf SVM : C:24, g:71 training score:0.976625, test score:0.747500
# rbf SVM : C:24, g:72 training score:0.976750, test score:0.746500
# rbf SVM : C:24, g:73 training score:0.977500, test score:0.746000
# rbf SVM : C:24, g:74 training score:0.978000, test score:0.746500
# rbf SVM : C:24, g:75 training score:0.978125, test score:0.747000
# rbf SVM : C:24, g:76 training score:0.978750, test score:0.746000
# rbf SVM : C:24, g:77 training score:0.979375, test score:0.745500
# rbf SVM : C:24, g:78 training score:0.979375, test score:0.744000
# rbf SVM : C:24, g:79 training score:0.980125, test score:0.745000
# rbf SVM : C:24, g:80 training score:0.980500, test score:0.745500
# rbf SVM : C:24, g:81 training score:0.981000, test score:0.746000
# rbf SVM : C:24, g:82 training score:0.981750, test score:0.746000
# rbf SVM : C:24, g:83 training score:0.982000, test score:0.746500
# rbf SVM : C:24, g:84 training score:0.982750, test score:0.746500
# rbf SVM : C:24, g:85 training score:0.982875, test score:0.748500
# rbf SVM : C:24, g:86 training score:0.983000, test score:0.748500
# rbf SVM : C:24, g:87 training score:0.983500, test score:0.748000
# rbf SVM : C:24, g:88 training score:0.984375, test score:0.746500
# rbf SVM : C:24, g:89 training score:0.984750, test score:0.746500
# rbf SVM : C:24, g:90 training score:0.985250, test score:0.746500
# rbf SVM : C:24, g:91 training score:0.985250, test score:0.746000
# rbf SVM : C:24, g:92 training score:0.985375, test score:0.745500
# rbf SVM : C:24, g:93 training score:0.985500, test score:0.745500
# rbf SVM : C:24, g:94 training score:0.985875, test score:0.746000
# rbf SVM : C:24, g:95 training score:0.986375, test score:0.746000
# rbf SVM : C:24, g:96 training score:0.986625, test score:0.744000
# rbf SVM : C:24, g:97 training score:0.987000, test score:0.745500
# rbf SVM : C:24, g:98 training score:0.987250, test score:0.745000
# rbf SVM : C:24, g:99 training score:0.987625, test score:0.744000
# rbf SVM : C:25, g:1 training score:0.778750, test score:0.758500
# rbf SVM : C:25, g:2 training score:0.798750, test score:0.766000
# rbf SVM : C:25, g:3 training score:0.812625, test score:0.754500
# rbf SVM : C:25, g:4 training score:0.829125, test score:0.762000
# rbf SVM : C:25, g:5 training score:0.841000, test score:0.769500
# rbf SVM : C:25, g:6 training score:0.850625, test score:0.772000
# rbf SVM : C:25, g:7 training score:0.857375, test score:0.766500
# rbf SVM : C:25, g:8 training score:0.862250, test score:0.762500
# rbf SVM : C:25, g:9 training score:0.870375, test score:0.760000
# rbf SVM : C:25, g:10 training score:0.874750, test score:0.754500
# rbf SVM : C:25, g:11 training score:0.877375, test score:0.755000
# rbf SVM : C:25, g:12 training score:0.881125, test score:0.756000
# rbf SVM : C:25, g:13 training score:0.885875, test score:0.751000
# rbf SVM : C:25, g:14 training score:0.889875, test score:0.751500
# rbf SVM : C:25, g:15 training score:0.893375, test score:0.752000
# rbf SVM : C:25, g:16 training score:0.898000, test score:0.751000
# rbf SVM : C:25, g:17 training score:0.902875, test score:0.751500
# rbf SVM : C:25, g:18 training score:0.908000, test score:0.752000
# rbf SVM : C:25, g:19 training score:0.910375, test score:0.752000
# rbf SVM : C:25, g:20 training score:0.913500, test score:0.748500
# rbf SVM : C:25, g:21 training score:0.916500, test score:0.747500
# rbf SVM : C:25, g:22 training score:0.920125, test score:0.747000
# rbf SVM : C:25, g:23 training score:0.922250, test score:0.747500
# rbf SVM : C:25, g:24 training score:0.924875, test score:0.752500
# rbf SVM : C:25, g:25 training score:0.926500, test score:0.754500
# rbf SVM : C:25, g:26 training score:0.927750, test score:0.753500
# rbf SVM : C:25, g:27 training score:0.929250, test score:0.752500
# rbf SVM : C:25, g:28 training score:0.930250, test score:0.752000
# rbf SVM : C:25, g:29 training score:0.931375, test score:0.754000
# rbf SVM : C:25, g:30 training score:0.932875, test score:0.754000
# rbf SVM : C:25, g:31 training score:0.935250, test score:0.755500
# rbf SVM : C:25, g:32 training score:0.937500, test score:0.755500
# rbf SVM : C:25, g:33 training score:0.941000, test score:0.756000
# rbf SVM : C:25, g:34 training score:0.942750, test score:0.756000
# rbf SVM : C:25, g:35 training score:0.944125, test score:0.755000
# rbf SVM : C:25, g:36 training score:0.944500, test score:0.757000
# rbf SVM : C:25, g:37 training score:0.945500, test score:0.759000
# rbf SVM : C:25, g:38 training score:0.947125, test score:0.756500
# rbf SVM : C:25, g:39 training score:0.949125, test score:0.756000
# rbf SVM : C:25, g:40 training score:0.950125, test score:0.757500
# rbf SVM : C:25, g:41 training score:0.950750, test score:0.757000
# rbf SVM : C:25, g:42 training score:0.952125, test score:0.755500
# rbf SVM : C:25, g:43 training score:0.953250, test score:0.754500
# rbf SVM : C:25, g:44 training score:0.953875, test score:0.753500
# rbf SVM : C:25, g:45 training score:0.955000, test score:0.752500
# rbf SVM : C:25, g:46 training score:0.956000, test score:0.752000
# rbf SVM : C:25, g:47 training score:0.956875, test score:0.752000
# rbf SVM : C:25, g:48 training score:0.957625, test score:0.752500
# rbf SVM : C:25, g:49 training score:0.958750, test score:0.750500
# rbf SVM : C:25, g:50 training score:0.959375, test score:0.749500
# rbf SVM : C:25, g:51 training score:0.960500, test score:0.749500
# rbf SVM : C:25, g:52 training score:0.961500, test score:0.751000
# rbf SVM : C:25, g:53 training score:0.962750, test score:0.751000
# rbf SVM : C:25, g:54 training score:0.964125, test score:0.749000
# rbf SVM : C:25, g:55 training score:0.965625, test score:0.748500
# rbf SVM : C:25, g:56 training score:0.967375, test score:0.746000
# rbf SVM : C:25, g:57 training score:0.968000, test score:0.745500
# rbf SVM : C:25, g:58 training score:0.968750, test score:0.743500
# rbf SVM : C:25, g:59 training score:0.969250, test score:0.744000
# rbf SVM : C:25, g:60 training score:0.969875, test score:0.745500
# rbf SVM : C:25, g:61 training score:0.970500, test score:0.745500
# rbf SVM : C:25, g:62 training score:0.971750, test score:0.745000
# rbf SVM : C:25, g:63 training score:0.972625, test score:0.743500
# rbf SVM : C:25, g:64 training score:0.973000, test score:0.747000
# rbf SVM : C:25, g:65 training score:0.973625, test score:0.746000
# rbf SVM : C:25, g:66 training score:0.974375, test score:0.746000
# rbf SVM : C:25, g:67 training score:0.975125, test score:0.747000
# rbf SVM : C:25, g:68 training score:0.975375, test score:0.748500
# rbf SVM : C:25, g:69 training score:0.976000, test score:0.746500
# rbf SVM : C:25, g:70 training score:0.976500, test score:0.747500
# rbf SVM : C:25, g:71 training score:0.976750, test score:0.748000
# rbf SVM : C:25, g:72 training score:0.977250, test score:0.746000
# rbf SVM : C:25, g:73 training score:0.977750, test score:0.746500
# rbf SVM : C:25, g:74 training score:0.978125, test score:0.747000
# rbf SVM : C:25, g:75 training score:0.978625, test score:0.745500
# rbf SVM : C:25, g:76 training score:0.979250, test score:0.745500
# rbf SVM : C:25, g:77 training score:0.979500, test score:0.745000
# rbf SVM : C:25, g:78 training score:0.980125, test score:0.744500
# rbf SVM : C:25, g:79 training score:0.980500, test score:0.745500
# rbf SVM : C:25, g:80 training score:0.981125, test score:0.746000
# rbf SVM : C:25, g:81 training score:0.981625, test score:0.745500
# rbf SVM : C:25, g:82 training score:0.982000, test score:0.746500
# rbf SVM : C:25, g:83 training score:0.982875, test score:0.746500
# rbf SVM : C:25, g:84 training score:0.982750, test score:0.748000
# rbf SVM : C:25, g:85 training score:0.983250, test score:0.748500
# rbf SVM : C:25, g:86 training score:0.983625, test score:0.748500
# rbf SVM : C:25, g:87 training score:0.984500, test score:0.747000
# rbf SVM : C:25, g:88 training score:0.984875, test score:0.746000
# rbf SVM : C:25, g:89 training score:0.985250, test score:0.746000
# rbf SVM : C:25, g:90 training score:0.985375, test score:0.745500
# rbf SVM : C:25, g:91 training score:0.985500, test score:0.745000
# rbf SVM : C:25, g:92 training score:0.985500, test score:0.745000
# rbf SVM : C:25, g:93 training score:0.986000, test score:0.745500
# rbf SVM : C:25, g:94 training score:0.986250, test score:0.745500
# rbf SVM : C:25, g:95 training score:0.986750, test score:0.745500
# rbf SVM : C:25, g:96 training score:0.986875, test score:0.744500
# rbf SVM : C:25, g:97 training score:0.987250, test score:0.744500
# rbf SVM : C:25, g:98 training score:0.988000, test score:0.744500
# rbf SVM : C:25, g:99 training score:0.988000, test score:0.744000
# rbf SVM : C:26, g:1 training score:0.779625, test score:0.760000
# rbf SVM : C:26, g:2 training score:0.799375, test score:0.764500
# rbf SVM : C:26, g:3 training score:0.813000, test score:0.755000
# rbf SVM : C:26, g:4 training score:0.829750, test score:0.762500
# rbf SVM : C:26, g:5 training score:0.841625, test score:0.769500
# rbf SVM : C:26, g:6 training score:0.851125, test score:0.771500
# rbf SVM : C:26, g:7 training score:0.858250, test score:0.765000
# rbf SVM : C:26, g:8 training score:0.862875, test score:0.762500
# rbf SVM : C:26, g:9 training score:0.871000, test score:0.759000
# rbf SVM : C:26, g:10 training score:0.875125, test score:0.756000
# rbf SVM : C:26, g:11 training score:0.877000, test score:0.755500
# rbf SVM : C:26, g:12 training score:0.881625, test score:0.756500
# rbf SVM : C:26, g:13 training score:0.886625, test score:0.751000
# rbf SVM : C:26, g:14 training score:0.889875, test score:0.752000
# rbf SVM : C:26, g:15 training score:0.894125, test score:0.752500
# rbf SVM : C:26, g:16 training score:0.898250, test score:0.750500
# rbf SVM : C:26, g:17 training score:0.904125, test score:0.750500
# rbf SVM : C:26, g:18 training score:0.908375, test score:0.751500
# rbf SVM : C:26, g:19 training score:0.910750, test score:0.752000
# rbf SVM : C:26, g:20 training score:0.914375, test score:0.747500
# rbf SVM : C:26, g:21 training score:0.917250, test score:0.747500
# rbf SVM : C:26, g:22 training score:0.920500, test score:0.746500
# rbf SVM : C:26, g:23 training score:0.923375, test score:0.747000
# rbf SVM : C:26, g:24 training score:0.925125, test score:0.752000
# rbf SVM : C:26, g:25 training score:0.927500, test score:0.755000
# rbf SVM : C:26, g:26 training score:0.928500, test score:0.753000
# rbf SVM : C:26, g:27 training score:0.929625, test score:0.752000
# rbf SVM : C:26, g:28 training score:0.930125, test score:0.754000
# rbf SVM : C:26, g:29 training score:0.931750, test score:0.754000
# rbf SVM : C:26, g:30 training score:0.933500, test score:0.753500
# rbf SVM : C:26, g:31 training score:0.936125, test score:0.754500
# rbf SVM : C:26, g:32 training score:0.939000, test score:0.754500
# rbf SVM : C:26, g:33 training score:0.941000, test score:0.756500
# rbf SVM : C:26, g:34 training score:0.943500, test score:0.755500
# rbf SVM : C:26, g:35 training score:0.944375, test score:0.756000
# rbf SVM : C:26, g:36 training score:0.945000, test score:0.757000
# rbf SVM : C:26, g:37 training score:0.946125, test score:0.758500
# rbf SVM : C:26, g:38 training score:0.947875, test score:0.757000
# rbf SVM : C:26, g:39 training score:0.949750, test score:0.755500
# rbf SVM : C:26, g:40 training score:0.950375, test score:0.757500
# rbf SVM : C:26, g:41 training score:0.951000, test score:0.757000
# rbf SVM : C:26, g:42 training score:0.952750, test score:0.755500
# rbf SVM : C:26, g:43 training score:0.953500, test score:0.752000
# rbf SVM : C:26, g:44 training score:0.954375, test score:0.753000
# rbf SVM : C:26, g:45 training score:0.955500, test score:0.752000
# rbf SVM : C:26, g:46 training score:0.956750, test score:0.752000
# rbf SVM : C:26, g:47 training score:0.957500, test score:0.751500
# rbf SVM : C:26, g:48 training score:0.958125, test score:0.751500
# rbf SVM : C:26, g:49 training score:0.958875, test score:0.750500
# rbf SVM : C:26, g:50 training score:0.960125, test score:0.749500
# rbf SVM : C:26, g:51 training score:0.960875, test score:0.749000
# rbf SVM : C:26, g:52 training score:0.962375, test score:0.750500
# rbf SVM : C:26, g:53 training score:0.964000, test score:0.750500
# rbf SVM : C:26, g:54 training score:0.964750, test score:0.749500
# rbf SVM : C:26, g:55 training score:0.966625, test score:0.747000
# rbf SVM : C:26, g:56 training score:0.967750, test score:0.744500
# rbf SVM : C:26, g:57 training score:0.968500, test score:0.743500
# rbf SVM : C:26, g:58 training score:0.969125, test score:0.743000
# rbf SVM : C:26, g:59 training score:0.969875, test score:0.745500
# rbf SVM : C:26, g:60 training score:0.970250, test score:0.745500
# rbf SVM : C:26, g:61 training score:0.971500, test score:0.745000
# rbf SVM : C:26, g:62 training score:0.972125, test score:0.744500
# rbf SVM : C:26, g:63 training score:0.973000, test score:0.745500
# rbf SVM : C:26, g:64 training score:0.973750, test score:0.746500
# rbf SVM : C:26, g:65 training score:0.974500, test score:0.745500
# rbf SVM : C:26, g:66 training score:0.975125, test score:0.747000
# rbf SVM : C:26, g:67 training score:0.975250, test score:0.748000
# rbf SVM : C:26, g:68 training score:0.975875, test score:0.748000
# rbf SVM : C:26, g:69 training score:0.976500, test score:0.747500
# rbf SVM : C:26, g:70 training score:0.976750, test score:0.747500
# rbf SVM : C:26, g:71 training score:0.977125, test score:0.749000
# rbf SVM : C:26, g:72 training score:0.977750, test score:0.747500
# rbf SVM : C:26, g:73 training score:0.978125, test score:0.746500
# rbf SVM : C:26, g:74 training score:0.978500, test score:0.746000
# rbf SVM : C:26, g:75 training score:0.979250, test score:0.746000
# rbf SVM : C:26, g:76 training score:0.979875, test score:0.745500
# rbf SVM : C:26, g:77 training score:0.980125, test score:0.745500
# rbf SVM : C:26, g:78 training score:0.980500, test score:0.746000
# rbf SVM : C:26, g:79 training score:0.981125, test score:0.746000
# rbf SVM : C:26, g:80 training score:0.981625, test score:0.745500
# rbf SVM : C:26, g:81 training score:0.982125, test score:0.745500
# rbf SVM : C:26, g:82 training score:0.982750, test score:0.746500
# rbf SVM : C:26, g:83 training score:0.982750, test score:0.748000
# rbf SVM : C:26, g:84 training score:0.983250, test score:0.748500
# rbf SVM : C:26, g:85 training score:0.983875, test score:0.749000
# rbf SVM : C:26, g:86 training score:0.984500, test score:0.747000
# rbf SVM : C:26, g:87 training score:0.984875, test score:0.746000
# rbf SVM : C:26, g:88 training score:0.985125, test score:0.746000
# rbf SVM : C:26, g:89 training score:0.985375, test score:0.746000
# rbf SVM : C:26, g:90 training score:0.985500, test score:0.745000
# rbf SVM : C:26, g:91 training score:0.985625, test score:0.745000
# rbf SVM : C:26, g:92 training score:0.985875, test score:0.745500
# rbf SVM : C:26, g:93 training score:0.986375, test score:0.745500
# rbf SVM : C:26, g:94 training score:0.986625, test score:0.745500
# rbf SVM : C:26, g:95 training score:0.987125, test score:0.745500
# rbf SVM : C:26, g:96 training score:0.987250, test score:0.743500
# rbf SVM : C:26, g:97 training score:0.988000, test score:0.744500
# rbf SVM : C:26, g:98 training score:0.988000, test score:0.744500
# rbf SVM : C:26, g:99 training score:0.988125, test score:0.745000
# rbf SVM : C:27, g:1 training score:0.780500, test score:0.760000
# rbf SVM : C:27, g:2 training score:0.799625, test score:0.763500
# rbf SVM : C:27, g:3 training score:0.813500, test score:0.755500
# rbf SVM : C:27, g:4 training score:0.829750, test score:0.762000
# rbf SVM : C:27, g:5 training score:0.841875, test score:0.769500
# rbf SVM : C:27, g:6 training score:0.852250, test score:0.772000
# rbf SVM : C:27, g:7 training score:0.858000, test score:0.765500
# rbf SVM : C:27, g:8 training score:0.863500, test score:0.762000
# rbf SVM : C:27, g:9 training score:0.872375, test score:0.759000
# rbf SVM : C:27, g:10 training score:0.875875, test score:0.755500
# rbf SVM : C:27, g:11 training score:0.877875, test score:0.754500
# rbf SVM : C:27, g:12 training score:0.882500, test score:0.754500
# rbf SVM : C:27, g:13 training score:0.886750, test score:0.753000
# rbf SVM : C:27, g:14 training score:0.890375, test score:0.752000
# rbf SVM : C:27, g:15 training score:0.894875, test score:0.752500
# rbf SVM : C:27, g:16 training score:0.898750, test score:0.752500
# rbf SVM : C:27, g:17 training score:0.905125, test score:0.750500
# rbf SVM : C:27, g:18 training score:0.909125, test score:0.751000
# rbf SVM : C:27, g:19 training score:0.911500, test score:0.749500
# rbf SVM : C:27, g:20 training score:0.915000, test score:0.747500
# rbf SVM : C:27, g:21 training score:0.918000, test score:0.748000
# rbf SVM : C:27, g:22 training score:0.921375, test score:0.747000
# rbf SVM : C:27, g:23 training score:0.923375, test score:0.749000
# rbf SVM : C:27, g:24 training score:0.925500, test score:0.752500
# rbf SVM : C:27, g:25 training score:0.927875, test score:0.753500
# rbf SVM : C:27, g:26 training score:0.928750, test score:0.753500
# rbf SVM : C:27, g:27 training score:0.930125, test score:0.752500
# rbf SVM : C:27, g:28 training score:0.930000, test score:0.754000
# rbf SVM : C:27, g:29 training score:0.932250, test score:0.754000
# rbf SVM : C:27, g:30 training score:0.934375, test score:0.756000
# rbf SVM : C:27, g:31 training score:0.936500, test score:0.753500
# rbf SVM : C:27, g:32 training score:0.939625, test score:0.754000
# rbf SVM : C:27, g:33 training score:0.942250, test score:0.755500
# rbf SVM : C:27, g:34 training score:0.943875, test score:0.754000
# rbf SVM : C:27, g:35 training score:0.944375, test score:0.756000
# rbf SVM : C:27, g:36 training score:0.945250, test score:0.758000
# rbf SVM : C:27, g:37 training score:0.946875, test score:0.758500
# rbf SVM : C:27, g:38 training score:0.948875, test score:0.756500
# rbf SVM : C:27, g:39 training score:0.950250, test score:0.757000
# rbf SVM : C:27, g:40 training score:0.950625, test score:0.757500
# rbf SVM : C:27, g:41 training score:0.951875, test score:0.756000
# rbf SVM : C:27, g:42 training score:0.953125, test score:0.754500
# rbf SVM : C:27, g:43 training score:0.953625, test score:0.753500
# rbf SVM : C:27, g:44 training score:0.955000, test score:0.752500
# rbf SVM : C:27, g:45 training score:0.956000, test score:0.753000
# rbf SVM : C:27, g:46 training score:0.957375, test score:0.752000
# rbf SVM : C:27, g:47 training score:0.958250, test score:0.752500
# rbf SVM : C:27, g:48 training score:0.958750, test score:0.751000
# rbf SVM : C:27, g:49 training score:0.959625, test score:0.750000
# rbf SVM : C:27, g:50 training score:0.960375, test score:0.749000
# rbf SVM : C:27, g:51 training score:0.961750, test score:0.749500
# rbf SVM : C:27, g:52 training score:0.963375, test score:0.750000
# rbf SVM : C:27, g:53 training score:0.964500, test score:0.749000
# rbf SVM : C:27, g:54 training score:0.965875, test score:0.748000
# rbf SVM : C:27, g:55 training score:0.967625, test score:0.746500
# rbf SVM : C:27, g:56 training score:0.968375, test score:0.743500
# rbf SVM : C:27, g:57 training score:0.968875, test score:0.743000
# rbf SVM : C:27, g:58 training score:0.969375, test score:0.743000
# rbf SVM : C:27, g:59 training score:0.970000, test score:0.745000
# rbf SVM : C:27, g:60 training score:0.971000, test score:0.744500
# rbf SVM : C:27, g:61 training score:0.972000, test score:0.744500
# rbf SVM : C:27, g:62 training score:0.973000, test score:0.744000
# rbf SVM : C:27, g:63 training score:0.973375, test score:0.746000
# rbf SVM : C:27, g:64 training score:0.974250, test score:0.746000
# rbf SVM : C:27, g:65 training score:0.974625, test score:0.747000
# rbf SVM : C:27, g:66 training score:0.975375, test score:0.747500
# rbf SVM : C:27, g:67 training score:0.975750, test score:0.747500
# rbf SVM : C:27, g:68 training score:0.976375, test score:0.747000
# rbf SVM : C:27, g:69 training score:0.976875, test score:0.748000
# rbf SVM : C:27, g:70 training score:0.977125, test score:0.749500
# rbf SVM : C:27, g:71 training score:0.977500, test score:0.747500
# rbf SVM : C:27, g:72 training score:0.978125, test score:0.748000
# rbf SVM : C:27, g:73 training score:0.978375, test score:0.746500
# rbf SVM : C:27, g:74 training score:0.979500, test score:0.746000
# rbf SVM : C:27, g:75 training score:0.980000, test score:0.746500
# rbf SVM : C:27, g:76 training score:0.980125, test score:0.745000
# rbf SVM : C:27, g:77 training score:0.980625, test score:0.747000
# rbf SVM : C:27, g:78 training score:0.980875, test score:0.746500
# rbf SVM : C:27, g:79 training score:0.981375, test score:0.746000
# rbf SVM : C:27, g:80 training score:0.982125, test score:0.745500
# rbf SVM : C:27, g:81 training score:0.982625, test score:0.745500
# rbf SVM : C:27, g:82 training score:0.982750, test score:0.748500
# rbf SVM : C:27, g:83 training score:0.983250, test score:0.748000
# rbf SVM : C:27, g:84 training score:0.983750, test score:0.748000
# rbf SVM : C:27, g:85 training score:0.984375, test score:0.747000
# rbf SVM : C:27, g:86 training score:0.985000, test score:0.746000
# rbf SVM : C:27, g:87 training score:0.985125, test score:0.746500
# rbf SVM : C:27, g:88 training score:0.985250, test score:0.745500
# rbf SVM : C:27, g:89 training score:0.985500, test score:0.744500
# rbf SVM : C:27, g:90 training score:0.985750, test score:0.745000
# rbf SVM : C:27, g:91 training score:0.985875, test score:0.745000
# rbf SVM : C:27, g:92 training score:0.986375, test score:0.745500
# rbf SVM : C:27, g:93 training score:0.986875, test score:0.745000
# rbf SVM : C:27, g:94 training score:0.987125, test score:0.745500
# rbf SVM : C:27, g:95 training score:0.987250, test score:0.745000
# rbf SVM : C:27, g:96 training score:0.988000, test score:0.743500
# rbf SVM : C:27, g:97 training score:0.988125, test score:0.745000
# rbf SVM : C:27, g:98 training score:0.988125, test score:0.744500
# rbf SVM : C:27, g:99 training score:0.988125, test score:0.744500
# rbf SVM : C:28, g:1 training score:0.780500, test score:0.760000
# rbf SVM : C:28, g:2 training score:0.799125, test score:0.763000
# rbf SVM : C:28, g:3 training score:0.814375, test score:0.756000
# rbf SVM : C:28, g:4 training score:0.830125, test score:0.762500
# rbf SVM : C:28, g:5 training score:0.842375, test score:0.769000
# rbf SVM : C:28, g:6 training score:0.853000, test score:0.771000
# rbf SVM : C:28, g:7 training score:0.858250, test score:0.764500
# rbf SVM : C:28, g:8 training score:0.864125, test score:0.761000
# rbf SVM : C:28, g:9 training score:0.872375, test score:0.756500
# rbf SVM : C:28, g:10 training score:0.876625, test score:0.756500
# rbf SVM : C:28, g:11 training score:0.878375, test score:0.754000
# rbf SVM : C:28, g:12 training score:0.883250, test score:0.753000
# rbf SVM : C:28, g:13 training score:0.887375, test score:0.753000
# rbf SVM : C:28, g:14 training score:0.890625, test score:0.751500
# rbf SVM : C:28, g:15 training score:0.895250, test score:0.752000
# rbf SVM : C:28, g:16 training score:0.900750, test score:0.751500
# rbf SVM : C:28, g:17 training score:0.906000, test score:0.748500
# rbf SVM : C:28, g:18 training score:0.910000, test score:0.750500
# rbf SVM : C:28, g:19 training score:0.912750, test score:0.749000
# rbf SVM : C:28, g:20 training score:0.915625, test score:0.748500
# rbf SVM : C:28, g:21 training score:0.918750, test score:0.747500
# rbf SVM : C:28, g:22 training score:0.921750, test score:0.747000
# rbf SVM : C:28, g:23 training score:0.923875, test score:0.749500
# rbf SVM : C:28, g:24 training score:0.925875, test score:0.754000
# rbf SVM : C:28, g:25 training score:0.928250, test score:0.754000
# rbf SVM : C:28, g:26 training score:0.929500, test score:0.752000
# rbf SVM : C:28, g:27 training score:0.930125, test score:0.752000
# rbf SVM : C:28, g:28 training score:0.931250, test score:0.752500
# rbf SVM : C:28, g:29 training score:0.932625, test score:0.752500
# rbf SVM : C:28, g:30 training score:0.935125, test score:0.757000
# rbf SVM : C:28, g:31 training score:0.937125, test score:0.755000
# rbf SVM : C:28, g:32 training score:0.940875, test score:0.753500
# rbf SVM : C:28, g:33 training score:0.942750, test score:0.756000
# rbf SVM : C:28, g:34 training score:0.943875, test score:0.755500
# rbf SVM : C:28, g:35 training score:0.944625, test score:0.756000
# rbf SVM : C:28, g:36 training score:0.945750, test score:0.758500
# rbf SVM : C:28, g:37 training score:0.947750, test score:0.757500
# rbf SVM : C:28, g:38 training score:0.949250, test score:0.756000
# rbf SVM : C:28, g:39 training score:0.950625, test score:0.756500
# rbf SVM : C:28, g:40 training score:0.950875, test score:0.757000
# rbf SVM : C:28, g:41 training score:0.952750, test score:0.757000
# rbf SVM : C:28, g:42 training score:0.953500, test score:0.755500
# rbf SVM : C:28, g:43 training score:0.954250, test score:0.752500
# rbf SVM : C:28, g:44 training score:0.955250, test score:0.753500
# rbf SVM : C:28, g:45 training score:0.956625, test score:0.752000
# rbf SVM : C:28, g:46 training score:0.957500, test score:0.752500
# rbf SVM : C:28, g:47 training score:0.958250, test score:0.750500
# rbf SVM : C:28, g:48 training score:0.959125, test score:0.751500
# rbf SVM : C:28, g:49 training score:0.960250, test score:0.750500
# rbf SVM : C:28, g:50 training score:0.960875, test score:0.748500
# rbf SVM : C:28, g:51 training score:0.962750, test score:0.749500
# rbf SVM : C:28, g:52 training score:0.964000, test score:0.750000
# rbf SVM : C:28, g:53 training score:0.965000, test score:0.747000
# rbf SVM : C:28, g:54 training score:0.967000, test score:0.746500
# rbf SVM : C:28, g:55 training score:0.968000, test score:0.745000
# rbf SVM : C:28, g:56 training score:0.968625, test score:0.743500
# rbf SVM : C:28, g:57 training score:0.969000, test score:0.743000
# rbf SVM : C:28, g:58 training score:0.970125, test score:0.744000
# rbf SVM : C:28, g:59 training score:0.970375, test score:0.745500
# rbf SVM : C:28, g:60 training score:0.972000, test score:0.744500
# rbf SVM : C:28, g:61 training score:0.972625, test score:0.744000
# rbf SVM : C:28, g:62 training score:0.973000, test score:0.746000
# rbf SVM : C:28, g:63 training score:0.973875, test score:0.746000
# rbf SVM : C:28, g:64 training score:0.974375, test score:0.746500
# rbf SVM : C:28, g:65 training score:0.975500, test score:0.746500
# rbf SVM : C:28, g:66 training score:0.975750, test score:0.747500
# rbf SVM : C:28, g:67 training score:0.976125, test score:0.748000
# rbf SVM : C:28, g:68 training score:0.976875, test score:0.748000
# rbf SVM : C:28, g:69 training score:0.977125, test score:0.748500
# rbf SVM : C:28, g:70 training score:0.977500, test score:0.749000
# rbf SVM : C:28, g:71 training score:0.978000, test score:0.748500
# rbf SVM : C:28, g:72 training score:0.978500, test score:0.748000
# rbf SVM : C:28, g:73 training score:0.978875, test score:0.747000
# rbf SVM : C:28, g:74 training score:0.980000, test score:0.746500
# rbf SVM : C:28, g:75 training score:0.980125, test score:0.746000
# rbf SVM : C:28, g:76 training score:0.980375, test score:0.746000
# rbf SVM : C:28, g:77 training score:0.980875, test score:0.747000
# rbf SVM : C:28, g:78 training score:0.981375, test score:0.746500
# rbf SVM : C:28, g:79 training score:0.982000, test score:0.747000
# rbf SVM : C:28, g:80 training score:0.982625, test score:0.746500
# rbf SVM : C:28, g:81 training score:0.982750, test score:0.748000
# rbf SVM : C:28, g:82 training score:0.983250, test score:0.747000
# rbf SVM : C:28, g:83 training score:0.983625, test score:0.747500
# rbf SVM : C:28, g:84 training score:0.984375, test score:0.748000
# rbf SVM : C:28, g:85 training score:0.984875, test score:0.746500
# rbf SVM : C:28, g:86 training score:0.985125, test score:0.746500
# rbf SVM : C:28, g:87 training score:0.985375, test score:0.746500
# rbf SVM : C:28, g:88 training score:0.985625, test score:0.745500
# rbf SVM : C:28, g:89 training score:0.985625, test score:0.744500
# rbf SVM : C:28, g:90 training score:0.986000, test score:0.745500
# rbf SVM : C:28, g:91 training score:0.986625, test score:0.745500
# rbf SVM : C:28, g:92 training score:0.986875, test score:0.745000
# rbf SVM : C:28, g:93 training score:0.987125, test score:0.745500
# rbf SVM : C:28, g:94 training score:0.987375, test score:0.745000
# rbf SVM : C:28, g:95 training score:0.988000, test score:0.745000
# rbf SVM : C:28, g:96 training score:0.988125, test score:0.743500
# rbf SVM : C:28, g:97 training score:0.988125, test score:0.745000
# rbf SVM : C:28, g:98 training score:0.988125, test score:0.744000
# rbf SVM : C:28, g:99 training score:0.988625, test score:0.743500
# rbf SVM : C:29, g:1 training score:0.780375, test score:0.760000
# rbf SVM : C:29, g:2 training score:0.798750, test score:0.763500
# rbf SVM : C:29, g:3 training score:0.815500, test score:0.756000
# rbf SVM : C:29, g:4 training score:0.830375, test score:0.761500
# rbf SVM : C:29, g:5 training score:0.842500, test score:0.768000
# rbf SVM : C:29, g:6 training score:0.852875, test score:0.770000
# rbf SVM : C:29, g:7 training score:0.858000, test score:0.765000
# rbf SVM : C:29, g:8 training score:0.864375, test score:0.761000
# rbf SVM : C:29, g:9 training score:0.872500, test score:0.757000
# rbf SVM : C:29, g:10 training score:0.876375, test score:0.756000
# rbf SVM : C:29, g:11 training score:0.878625, test score:0.754500
# rbf SVM : C:29, g:12 training score:0.884125, test score:0.754000
# rbf SVM : C:29, g:13 training score:0.888250, test score:0.752500
# rbf SVM : C:29, g:14 training score:0.890750, test score:0.752000
# rbf SVM : C:29, g:15 training score:0.895500, test score:0.752000
# rbf SVM : C:29, g:16 training score:0.901375, test score:0.751000
# rbf SVM : C:29, g:17 training score:0.907000, test score:0.749500
# rbf SVM : C:29, g:18 training score:0.910250, test score:0.750500
# rbf SVM : C:29, g:19 training score:0.913000, test score:0.749000
# rbf SVM : C:29, g:20 training score:0.915750, test score:0.749000
# rbf SVM : C:29, g:21 training score:0.919250, test score:0.747000
# rbf SVM : C:29, g:22 training score:0.921875, test score:0.747500
# rbf SVM : C:29, g:23 training score:0.924625, test score:0.752500
# rbf SVM : C:29, g:24 training score:0.926500, test score:0.755000
# rbf SVM : C:29, g:25 training score:0.928875, test score:0.754000
# rbf SVM : C:29, g:26 training score:0.929500, test score:0.751500
# rbf SVM : C:29, g:27 training score:0.930250, test score:0.752000
# rbf SVM : C:29, g:28 training score:0.931875, test score:0.752500
# rbf SVM : C:29, g:29 training score:0.933125, test score:0.754000
# rbf SVM : C:29, g:30 training score:0.935500, test score:0.756500
# rbf SVM : C:29, g:31 training score:0.938375, test score:0.753500
# rbf SVM : C:29, g:32 training score:0.941375, test score:0.754000
# rbf SVM : C:29, g:33 training score:0.943500, test score:0.756000
# rbf SVM : C:29, g:34 training score:0.944250, test score:0.756000
# rbf SVM : C:29, g:35 training score:0.944750, test score:0.756500
# ...
# rbf SVM : C:29, g:80 training score:0.982750, test score:0.747500
# rbf SVM : C:29, g:81 training score:0.983250, test score:0.748000
# rbf SVM : C:29, g:82 training score:0.983750, test score:0.747000
# rbf SVM : C:29, g:83 training score:0.984375, test score:0.748000
# rbf SVM : C:29, g:84 training score:0.984875, test score:0.747000
# rbf SVM : C:29, g:85 training score:0.985125, test score:0.747500
# rbf SVM : C:29, g:86 training score:0.985375, test score:0.747000
# rbf SVM : C:29, g:87 training score:0.985500, test score:0.746000
# rbf SVM : C:29, g:88 training score:0.985625, test score:0.745500
# rbf SVM : C:29, g:89 training score:0.986125, test score:0.745000
# rbf SVM : C:29, g:90 training score:0.986625, test score:0.745500
# rbf SVM : C:29, g:91 training score:0.986875, test score:0.745000
# rbf SVM : C:29, g:92 training score:0.986875, test score:0.745500
# rbf SVM : C:29, g:93 training score:0.987375, test score:0.745000
# rbf SVM : C:29, g:94 training score:0.988000, test score:0.745000
# rbf SVM : C:29, g:95 training score:0.988125, test score:0.745000
# rbf SVM : C:29, g:96 training score:0.988125, test score:0.743500
# rbf SVM : C:29, g:97 training score:0.988375, test score:0.744000
# rbf SVM : C:29, g:98 training score:0.988625, test score:0.743500
# rbf SVM : C:29, g:99 training score:0.988750, test score:0.744000
# rbf SVM : C:30, g:1 training score:0.780000, test score:0.760500
# rbf SVM : C:30, g:2 training score:0.798875, test score:0.764500
# rbf SVM : C:30, g:3 training score:0.816000, test score:0.755000
# rbf SVM : C:30, g:4 training score:0.830750, test score:0.762500
# rbf SVM : C:30, g:5 training score:0.843625, test score:0.765500
# rbf SVM : C:30, g:6 training score:0.853000, test score:0.770500
# rbf SVM : C:30, g:7 training score:0.858125, test score:0.764500
# rbf SVM : C:30, g:8 training score:0.864250, test score:0.762000
# rbf SVM : C:30, g:9 training score:0.872875, test score:0.757000
# rbf SVM : C:30, g:10 training score:0.876125, test score:0.755500
# rbf SVM : C:30, g:11 training score:0.879000, test score:0.755000
# rbf SVM : C:30, g:12 training score:0.884500, test score:0.752500
# rbf SVM : C:30, g:13 training score:0.888375, test score:0.752500
# rbf SVM : C:30, g:14 training score:0.891250, test score:0.751500
# rbf SVM : C:30, g:15 training score:0.896375, test score:0.751500
# rbf SVM : C:30, g:16 training score:0.902000, test score:0.751500
# rbf SVM : C:30, g:17 training score:0.907750, test score:0.749500
# rbf SVM : C:30, g:18 training score:0.910750, test score:0.750000
# rbf SVM : C:30, g:19 training score:0.913750, test score:0.747500
# rbf SVM : C:30, g:20 training score:0.916625, test score:0.748500
# rbf SVM : C:30, g:21 training score:0.919375, test score:0.747500
# rbf SVM : C:30, g:22 training score:0.922250, test score:0.748500
# rbf SVM : C:30, g:23 training score:0.925000, test score:0.752500
# rbf SVM : C:30, g:24 training score:0.927000, test score:0.753000
# rbf SVM : C:30, g:25 training score:0.929000, test score:0.753500
# rbf SVM : C:30, g:26 training score:0.930625, test score:0.752000
# rbf SVM : C:30, g:27 training score:0.930875, test score:0.753000
# rbf SVM : C:30, g:28 training score:0.932000, test score:0.754000
# rbf SVM : C:30, g:29 training score:0.933625, test score:0.753500
# rbf SVM : C:30, g:30 training score:0.936250, test score:0.755000
# rbf SVM : C:30, g:31 training score:0.939625, test score:0.753000
# rbf SVM : C:30, g:32 training score:0.941750, test score:0.754000
# rbf SVM : C:30, g:33 training score:0.944125, test score:0.755500
# rbf SVM : C:30, g:34 training score:0.943875, test score:0.755500
# rbf SVM : C:30, g:35 training score:0.945625, test score:0.756500
# rbf SVM : C:30, g:36 training score:0.947375, test score:0.759000
# rbf SVM : C:30, g:37 training score:0.949000, test score:0.756500
# rbf SVM : C:30, g:38 training score:0.950250, test score:0.757500
# rbf SVM : C:30, g:39 training score:0.951125, test score:0.757000
# rbf SVM : C:30, g:40 training score:0.952000, test score:0.756000
# rbf SVM : C:30, g:41 training score:0.953625, test score:0.757000
# rbf SVM : C:30, g:42 training score:0.953875, test score:0.754500
# rbf SVM : C:30, g:43 training score:0.954875, test score:0.753500
# rbf SVM : C:30, g:44 training score:0.956375, test score:0.752500
# rbf SVM : C:30, g:45 training score:0.957375, test score:0.752500
# rbf SVM : C:30, g:46 training score:0.958500, test score:0.751000
# rbf SVM : C:30, g:47 training score:0.958875, test score:0.750000
# rbf SVM : C:30, g:48 training score:0.960500, test score:0.752500
# rbf SVM : C:30, g:49 training score:0.961125, test score:0.750500
# rbf SVM : C:30, g:50 training score:0.962625, test score:0.747500
# rbf SVM : C:30, g:51 training score:0.964125, test score:0.747500
# rbf SVM : C:30, g:52 training score:0.964750, test score:0.746500
# rbf SVM : C:30, g:53 training score:0.967000, test score:0.747000
# rbf SVM : C:30, g:54 training score:0.967750, test score:0.744500
# rbf SVM : C:30, g:55 training score:0.968750, test score:0.743000
# rbf SVM : C:30, g:56 training score:0.969250, test score:0.744000
# rbf SVM : C:30, g:57 training score:0.970375, test score:0.745000
# rbf SVM : C:30, g:58 training score:0.970750, test score:0.745000
# rbf SVM : C:30, g:59 training score:0.971875, test score:0.745000
# rbf SVM : C:30, g:60 training score:0.973125, test score:0.745000
# rbf SVM : C:30, g:61 training score:0.973000, test score:0.746000
# rbf SVM : C:30, g:62 training score:0.973875, test score:0.744000
# rbf SVM : C:30, g:63 training score:0.974625, test score:0.745500
# rbf SVM : C:30, g:64 training score:0.975500, test score:0.746000
# rbf SVM : C:30, g:65 training score:0.976000, test score:0.748000
# rbf SVM : C:30, g:66 training score:0.976500, test score:0.748000
# rbf SVM : C:30, g:67 training score:0.976625, test score:0.748000
# rbf SVM : C:30, g:68 training score:0.977000, test score:0.748500
# rbf SVM : C:30, g:69 training score:0.977625, test score:0.749500
# rbf SVM : C:30, g:70 training score:0.978250, test score:0.749000
# rbf SVM : C:30, g:71 training score:0.978625, test score:0.748500
# rbf SVM : C:30, g:72 training score:0.979625, test score:0.748000
# rbf SVM : C:30, g:73 training score:0.980375, test score:0.747500
# rbf SVM : C:30, g:74 training score:0.980500, test score:0.745500
# rbf SVM : C:30, g:75 training score:0.980750, test score:0.746500
# rbf SVM : C:30, g:76 training score:0.981000, test score:0.748000
# rbf SVM : C:30, g:77 training score:0.981875, test score:0.747500
# rbf SVM : C:30, g:78 training score:0.982500, test score:0.746500
# rbf SVM : C:30, g:79 training score:0.982750, test score:0.748000
# rbf SVM : C:30, g:80 training score:0.983250, test score:0.749000
# rbf SVM : C:30, g:81 training score:0.983625, test score:0.748000
# rbf SVM : C:30, g:82 training score:0.984250, test score:0.747000
# rbf SVM : C:30, g:83 training score:0.984625, test score:0.747000
# rbf SVM : C:30, g:84 training score:0.985250, test score:0.748000
# rbf SVM : C:30, g:85 training score:0.985375, test score:0.746500
# rbf SVM : C:30, g:86 training score:0.985500, test score:0.747500
# rbf SVM : C:30, g:87 training score:0.985625, test score:0.746000
# rbf SVM : C:30, g:88 training score:0.986125, test score:0.746000
# rbf SVM : C:30, g:89 training score:0.986750, test score:0.745000
# rbf SVM : C:30, g:90 training score:0.986750, test score:0.745000
# rbf SVM : C:30, g:91 training score:0.986875, test score:0.745500
# rbf SVM : C:30, g:92 training score:0.987375, test score:0.745000
# rbf SVM : C:30, g:93 training score:0.988000, test score:0.745000
# rbf SVM : C:30, g:94 training score:0.988125, test score:0.744500
# rbf SVM : C:30, g:95 training score:0.988125, test score:0.744000
# rbf SVM : C:30, g:96 training score:0.988375, test score:0.743500
# rbf SVM : C:30, g:97 training score:0.988625, test score:0.744000
# rbf SVM : C:30, g:98 training score:0.988875, test score:0.744500
# rbf SVM : C:30, g:99 training score:0.989250, test score:0.743000
# rbf SVM : C:31, g:1 training score:0.780375, test score:0.760000
# rbf SVM : C:31, g:2 training score:0.798875, test score:0.765000
# rbf SVM : C:31, g:3 training score:0.816625, test score:0.754000
# rbf SVM : C:31, g:4 training score:0.830875, test score:0.762000
# rbf SVM : C:31, g:5 training score:0.844125, test score:0.766500
# rbf SVM : C:31, g:6 training score:0.852625, test score:0.768000
# rbf SVM : C:31, g:7 training score:0.858000, test score:0.764500
# rbf SVM : C:31, g:8 training score:0.864875, test score:0.761000
# rbf SVM : C:31, g:9 training score:0.873375, test score:0.755500
# rbf SVM : C:31, g:10 training score:0.876625, test score:0.755500
# rbf SVM : C:31, g:11 training score:0.879125, test score:0.754500
# rbf SVM : C:31, g:12 training score:0.884375, test score:0.752500
# rbf SVM : C:31, g:13 training score:0.888500, test score:0.752500
# rbf SVM : C:31, g:14 training score:0.891875, test score:0.752500
# rbf SVM : C:31, g:15 training score:0.896375, test score:0.751000
# rbf SVM : C:31, g:16 training score:0.902375, test score:0.750500
# rbf SVM : C:31, g:17 training score:0.908250, test score:0.749500
# rbf SVM : C:31, g:18 training score:0.911375, test score:0.750500
# rbf SVM : C:31, g:19 training score:0.914375, test score:0.747000
# rbf SVM : C:31, g:20 training score:0.917375, test score:0.748000
# rbf SVM : C:31, g:21 training score:0.920250, test score:0.748000
# rbf SVM : C:31, g:22 training score:0.923125, test score:0.749000
# rbf SVM : C:31, g:23 training score:0.925375, test score:0.752500
# rbf SVM : C:31, g:24 training score:0.927625, test score:0.753000
# rbf SVM : C:31, g:25 training score:0.929000, test score:0.751500
# rbf SVM : C:31, g:26 training score:0.930125, test score:0.752500
# rbf SVM : C:31, g:27 training score:0.930375, test score:0.752000
# rbf SVM : C:31, g:28 training score:0.933000, test score:0.754500
# rbf SVM : C:31, g:29 training score:0.934125, test score:0.754500
# rbf SVM : C:31, g:30 training score:0.937250, test score:0.753500
# rbf SVM : C:31, g:31 training score:0.940250, test score:0.752000
# rbf SVM : C:31, g:32 training score:0.941875, test score:0.755500
# rbf SVM : C:31, g:33 training score:0.944500, test score:0.756500
# rbf SVM : C:31, g:34 training score:0.944375, test score:0.755000
# rbf SVM : C:31, g:35 training score:0.945875, test score:0.756500
# rbf SVM : C:31, g:36 training score:0.947875, test score:0.758500
# rbf SVM : C:31, g:37 training score:0.950000, test score:0.756000
# rbf SVM : C:31, g:38 training score:0.950375, test score:0.755000
# rbf SVM : C:31, g:39 training score:0.951375, test score:0.756500
# rbf SVM : C:31, g:40 training score:0.953125, test score:0.756500
# rbf SVM : C:31, g:41 training score:0.953625, test score:0.757500
# rbf SVM : C:31, g:42 training score:0.954625, test score:0.754500
# rbf SVM : C:31, g:43 training score:0.955250, test score:0.754500
# rbf SVM : C:31, g:44 training score:0.956750, test score:0.752000
# rbf SVM : C:31, g:45 training score:0.957500, test score:0.751000
# rbf SVM : C:31, g:46 training score:0.958500, test score:0.751500
# rbf SVM : C:31, g:47 training score:0.959500, test score:0.751500
# rbf SVM : C:31, g:48 training score:0.960875, test score:0.753000
# rbf SVM : C:31, g:49 training score:0.961375, test score:0.749500
# rbf SVM : C:31, g:50 training score:0.963625, test score:0.747000
# rbf SVM : C:31, g:51 training score:0.964375, test score:0.747000
# rbf SVM : C:31, g:52 training score:0.966000, test score:0.747000
# rbf SVM : C:31, g:53 training score:0.967625, test score:0.746500
# rbf SVM : C:31, g:54 training score:0.968250, test score:0.744000
# rbf SVM : C:31, g:55 training score:0.968750, test score:0.744000
# rbf SVM : C:31, g:56 training score:0.969750, test score:0.744500
# rbf SVM : C:31, g:57 training score:0.970375, test score:0.745000
# rbf SVM : C:31, g:58 training score:0.972000, test score:0.744500
# rbf SVM : C:31, g:59 training score:0.972250, test score:0.744500
# rbf SVM : C:31, g:60 training score:0.973000, test score:0.745000
# rbf SVM : C:31, g:61 training score:0.973500, test score:0.745000
# rbf SVM : C:31, g:62 training score:0.974375, test score:0.745000
# rbf SVM : C:31, g:63 training score:0.975250, test score:0.746000
# rbf SVM : C:31, g:64 training score:0.976000, test score:0.747000
# rbf SVM : C:31, g:65 training score:0.976250, test score:0.747000
# rbf SVM : C:31, g:66 training score:0.976625, test score:0.747000
# rbf SVM : C:31, g:67 training score:0.977000, test score:0.748000
# rbf SVM : C:31, g:68 training score:0.977375, test score:0.748500
# rbf SVM : C:31, g:69 training score:0.977750, test score:0.749000
# rbf SVM : C:31, g:70 training score:0.978625, test score:0.748500
# rbf SVM : C:31, g:71 training score:0.979250, test score:0.748000
# rbf SVM : C:31, g:72 training score:0.980375, test score:0.747500
# rbf SVM : C:31, g:73 training score:0.980375, test score:0.746500
# rbf SVM : C:31, g:74 training score:0.980625, test score:0.746000
# rbf SVM : C:31, g:75 training score:0.981000, test score:0.747500
# rbf SVM : C:31, g:76 training score:0.981625, test score:0.749000
# rbf SVM : C:31, g:77 training score:0.982500, test score:0.746500
# rbf SVM : C:31, g:78 training score:0.982750, test score:0.747000
# rbf SVM : C:31, g:79 training score:0.983250, test score:0.749500
# rbf SVM : C:31, g:80 training score:0.984000, test score:0.748000
# rbf SVM : C:31, g:81 training score:0.984250, test score:0.748500
# rbf SVM : C:31, g:82 training score:0.984625, test score:0.747500
# rbf SVM : C:31, g:83 training score:0.985125, test score:0.747500
# rbf SVM : C:31, g:84 training score:0.985375, test score:0.748000
# rbf SVM : C:31, g:85 training score:0.985500, test score:0.747500
# rbf SVM : C:31, g:86 training score:0.985750, test score:0.746500
# rbf SVM : C:31, g:87 training score:0.986125, test score:0.746000
# rbf SVM : C:31, g:88 training score:0.986625, test score:0.745500
# rbf SVM : C:31, g:89 training score:0.986625, test score:0.745000
# rbf SVM : C:31, g:90 training score:0.986875, test score:0.745000
# rbf SVM : C:31, g:91 training score:0.987250, test score:0.745500
# rbf SVM : C:31, g:92 training score:0.987875, test score:0.744500
# rbf SVM : C:31, g:93 training score:0.988000, test score:0.744500
# rbf SVM : C:31, g:94 training score:0.988125, test score:0.744500
# rbf SVM : C:31, g:95 training score:0.988375, test score:0.745000
# rbf SVM : C:31, g:96 training score:0.988500, test score:0.744000
# rbf SVM : C:31, g:97 training score:0.989000, test score:0.744000
# rbf SVM : C:31, g:98 training score:0.989250, test score:0.743000
# rbf SVM : C:31, g:99 training score:0.989250, test score:0.742500
# rbf SVM : C:32, g:1 training score:0.780375, test score:0.760000
# rbf SVM : C:32, g:2 training score:0.799125, test score:0.764000
# rbf SVM : C:32, g:3 training score:0.817250, test score:0.754500
# rbf SVM : C:32, g:4 training score:0.831500, test score:0.761500
# rbf SVM : C:32, g:5 training score:0.844500, test score:0.766000
# rbf SVM : C:32, g:6 training score:0.853250, test score:0.769000
# rbf SVM : C:32, g:7 training score:0.858250, test score:0.764500
# rbf SVM : C:32, g:8 training score:0.865250, test score:0.761500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-5c61087df364> in <module>()
#       5   for j in range(1,100):
#       6     svc=SVC(kernel='rbf',C=thisC, gamma= j )
# ----> 7     model=svc.fit(xtrain,ytrain)
#       8     scoreTrain=model.score(xtrain,ytrain)
#       9     scoreTest=model.score(xtest,ytest)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     253
#     254         seed = rnd.randint(np.iinfo("i").max)
# --> 255         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256         # see comment on the other call to np.iinfo in this file
#     257
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     331             epsilon=self.epsilon,
#     332             max_iter=self.max_iter,
# --> 333             random_seed=random_seed,
#     334         )
#     335
#
# KeyboardInterrupt:

# %% [markdown]
# rbf SVM : C:6, g:8 training score:0.846375, test score:0.775500

# %%
before = 0
now =  best

bc = 0
bg = 0

# %%
svc=SVC(kernel='rbf',C=6, gamma= 7.9 )
model=svc.fit(xtrain,ytrain)
scoreTrain=model.score(xtrain,ytrain)
scoreTest=model.score(xtest,ytest)
print("rbf SVM : C:{}, g:{} training score:{:2f}, test score:{:2f}".format
          (1,1,scoreTrain, scoreTest))
# Out:
# rbf SVM : C:1, g:1 training score:0.846250, test score:0.776000

# %% [markdown]
# rbf SVM : C:1, g:1 training score:0.846250, test score:0.776000

# %%
svc=SVC(kernel='rbf',C=6, gamma= 7.9 )
model=svc.fit(train,training_targets)

# %%
results = model.predict(test)

# %%
print(results)
# Out:
# [1 1 1 ... 0 0 1]

# %%
t_label = pd.read_csv('/content/gdrive/MyDrive/hoseo_AI/세얼간이_1차.csv')

df_test_label = pd.DataFrame({'분석대상': Test['분석대상'][0],
                              '정답지' : results[0]
                                  
},index=[0])

for i in range(1,len(Test)):
  new_df_test_label = {'분석대상': Test['분석대상'][i],
                              '정답지' : int(results[i])
                                  
}
  new_df_test_label = pd.DataFrame(new_df_test_label,index=[i])

  df_test_label = pd.concat([df_test_label,new_df_test_label], sort=False)
df_test_label.to_csv('/content/gdrive/MyDrive/hoseo_AI/세얼간이4차.csv',index=False)
